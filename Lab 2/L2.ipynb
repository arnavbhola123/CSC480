# %% [markdown]
# # CSC 480-F25 Lab 2: Task Decomposition, Multi‑Agent Design Patterns, and Communication Protocols

# %% [markdown]
# # Authors:

# %% [markdown]
# ***Arnav Bhola, Pranav Krishna***
#
# California Polytechnic State University, San Luis Obispo;
#
# Computer Science & Software Engineering Department

# %% [markdown]
# # Overview
#
# This lab focuses on:
# - Breaking down complex problems into smaller tasks (task decomposition)
# - Defining specialized agents with clear roles and responsibilities
# - Choosing appropriate multi-agent design patterns
# - Specifying communication protocols between agents
# - Implementing a three-agent system using AutoGen
#
# NOTE: If you already know what you're going to do for your final project, you may use this lab to make progress on it. Otherwise, treat this lab as a distinct exercise.
#
# ## Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Decompose a complex problem into a comprehensive set of constituent tasks
# - Identify and define the roles, responsibilities, and abilities of individual agents
# - Select and justify an appropriate multi-agent design pattern (Manager‑Worker, Sequential Pipeline, Collaborative Team)
# - Explain and apply foundational agent communication protocols at a high level (MCP, A2A)
# - Start thinking about the architecture of your project (agents, tasks, design pattern, and interaction protocols)

# %% [markdown]
# # Part 1: Task Decomposition and Agent Design

# %% [markdown]
# ## 1. Problem Statement & Task Decomposition
#
# **Main Problem:** [Describe the main problem your multi-agent system will solve]
#
# **Task Breakdown:** List the steps and sub-tasks needed to achieve the goal:
# 1. [Task 1]
# 2. [Task 2]
# 3. [Task 3]
# 4. [Additional tasks as needed]

# %% [markdown]
# ## 2. Agent Definition
#
# Define your primary agents with clear roles and responsibilities:
#
# ### Agent 1: [Agent Name]
# - **Role:** [Primary role/purpose]
# - **Responsibilities:** [What this agent is responsible for]
# - **Inputs:** [What data/information this agent receives]
# - **Outputs:** [What this agent produces]
# - **Success Criteria:** [How to measure if this agent succeeded]
#
# ### Agent 2: [Agent Name]
# - **Role:** [Primary role/purpose]
# - **Responsibilities:** [What this agent is responsible for]
# - **Inputs:** [What data/information this agent receives]
# - **Outputs:** [What this agent produces]
# - **Success Criteria:** [How to measure if this agent succeeded]
#
# ### Agent 3: [Agent Name]
# - **Role:** [Primary role/purpose]
# - **Responsibilities:** [What this agent is responsible for]
# - **Inputs:** [What data/information this agent receives]
# - **Outputs:** [What this agent produces]
# - **Success Criteria:** [How to measure if this agent succeeded]

# %% [markdown]
# ## 3. Design Pattern Selection
#
# **Chosen Pattern:** [Manager-Worker / Sequential Pipeline / Collaborative Team]
#
# **Justification:** [Explain why this pattern fits your workflow and constraints. Consider factors like task dependencies, parallelization opportunities, coordination complexity, etc.]

# %% [markdown]
# ## 4. Communication Design
#
# ### Model Context Protocol (MCP)
# **Shared Context & Tools:** [Describe the shared context and tools all agents need - schemas, access rules, etc.]
#
# ### Agent-to-Agent (A2A) Interactions
#
# #### Interaction 1: [Sender] → [Receiver]
# - **Purpose:** [What this interaction accomplishes]
# - **Key Fields:** [Important data/parameters exchanged]
# - **Message Format:** [Brief description of message structure]
#
# #### Interaction 2: [Sender] → [Receiver]
# - **Purpose:** [What this interaction accomplishes]
# - **Key Fields:** [Important data/parameters exchanged]
# - **Message Format:** [Brief description of message structure]

# %% [markdown]
# ## 5. Interaction Diagram
#
# [Create a flowchart or sequence diagram showing agents, your chosen pattern, and MCP/A2A interactions. You can use text-based diagrams, draw by hand and insert an image, or use diagramming tools.]
#
# ```
# Example text-based flow:
# User → Agent1 → Agent2 → Agent3 → User
#   ↓       ↓       ↓       ↓
#  MCP    A2A     A2A    Final
# Tool   Msg1    Msg2   Output
# ```

# %% [markdown]
# # Part 2: Three-Agent AutoGen Implementation

# %% [markdown]
# ## Environment Setup
#
# Install required packages and set up Azure OpenAI configuration.

# %%
# %pip install "autogen-core" "autogen-agentchat" "autogen-ext[openai,azure]"
# Out:
# Collecting autogen-core
#   Obtaining dependency information for autogen-core from https://files.pythonhosted.org/packages/33/83/8ad899fca9dd2d2b3e5e37be13dd9e6aee3e53a621041b0624d74b07e1ee/autogen_core-0.7.5-py3-none-any.whl.metadata
#   Downloading autogen_core-0.7.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting autogen-agentchat
#   Obtaining dependency information for autogen-agentchat from https://files.pythonhosted.org/packages/9e/82/23490a70837d77d691948863d393cef71a06d36903249f635b28f579292b/autogen_agentchat-0.7.5-py3-none-any.whl.metadata
#   Downloading autogen_agentchat-0.7.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting autogen-ext[azure,openai]
#   Obtaining dependency information for autogen-ext[azure,openai] from https://files.pythonhosted.org/packages/5c/10/9333ba6c532086cce7ec7fb39e36b9a08afdbc39e2d3519f00af712e403a/autogen_ext-0.7.5-py3-none-any.whl.metadata
#   Downloading autogen_ext-0.7.5-py3-none-any.whl.metadata (7.3 kB)
# Collecting jsonref~=1.1.0 (from autogen-core)
#   Obtaining dependency information for jsonref~=1.1.0 from https://files.pythonhosted.org/packages/0c/ec/e1db9922bceb168197a558a2b8c03a7963f1afe93517ddd3cf99f202f996/jsonref-1.1.0-py3-none-any.whl.metadata
#   Using cached jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting opentelemetry-api>=1.34.1 (from autogen-core)
#   Obtaining dependency information for opentelemetry-api>=1.34.1 from https://files.pythonhosted.org/packages/91/48/28ed9e55dcf2f453128df738210a980e09f4e468a456fa3c763dbc8be70a/opentelemetry_api-1.37.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pillow>=11.0.0 (from autogen-core)
#   Obtaining dependency information for pillow>=11.0.0 from https://files.pythonhosted.org/packages/2c/32/7e2ac19b5713657384cec55f89065fb306b06af008cfd87e572035b27119/pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting protobuf~=5.29.3 (from autogen-core)
#   Obtaining dependency information for protobuf~=5.29.3 from https://files.pythonhosted.org/packages/dd/73/10e1661c21f139f2c6ad9b23040ff36fee624310dc28fba20d33fdae124c/protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl.metadata
#   Using cached protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydantic<3.0.0,>=2.10.0 (from autogen-core)
#   Obtaining dependency information for pydantic<3.0.0,>=2.10.0 from https://files.pythonhosted.org/packages/3e/d3/108f2006987c58e76691d5ae5d200dd3e0f532cb4e5fa3560751c3a1feba/pydantic-2.11.9-py3-none-any.whl.metadata
#   Using cached pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting typing-extensions>=4.0.0 (from autogen-core)
#   Obtaining dependency information for typing-extensions>=4.0.0 from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting azure-ai-inference>=1.0.0b9 (from autogen-ext[azure,openai])
#   Obtaining dependency information for azure-ai-inference>=1.0.0b9 from https://files.pythonhosted.org/packages/4f/0f/27520da74769db6e58327d96c98e7b9a07ce686dff582c9a5ec60b03f9dd/azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata
#   Using cached azure_ai_inference-1.0.0b9-py3-none-any.whl.metadata (34 kB)
# Collecting azure-ai-projects>=1.0.0b11 (from autogen-ext[azure,openai])
#   Obtaining dependency information for azure-ai-projects>=1.0.0b11 from https://files.pythonhosted.org/packages/db/10/8b7bd070e3cc804343dab124ce66a3b7999a72d5be0e49232cbcd1d36e18/azure_ai_projects-1.1.0b4-py3-none-any.whl.metadata
#   Using cached azure_ai_projects-1.1.0b4-py3-none-any.whl.metadata (24 kB)
# Collecting azure-core (from autogen-ext[azure,openai])
#   Obtaining dependency information for azure-core from https://files.pythonhosted.org/packages/27/52/805980aa1ba18282077c484dba634ef0ede1e84eec8be9c92b2e162d0ed6/azure_core-1.35.1-py3-none-any.whl.metadata
#   Using cached azure_core-1.35.1-py3-none-any.whl.metadata (46 kB)
# Collecting azure-identity (from autogen-ext[azure,openai])
#   Obtaining dependency information for azure-identity from https://files.pythonhosted.org/packages/75/54/81683b6756676a22e037b209695b08008258e603f7e47c56834029c5922a/azure_identity-1.25.0-py3-none-any.whl.metadata
#   Using cached azure_identity-1.25.0-py3-none-any.whl.metadata (87 kB)
# Collecting azure-search-documents>=11.4.0 (from autogen-ext[azure,openai])
#   Obtaining dependency information for azure-search-documents>=11.4.0 from https://files.pythonhosted.org/packages/4b/f5/0f6b52567cbb33f1efba13060514ed7088a86de84d74b77cda17d278bcd9/azure_search_documents-11.5.3-py3-none-any.whl.metadata
#   Using cached azure_search_documents-11.5.3-py3-none-any.whl.metadata (23 kB)
# Collecting aiofiles (from autogen-ext[azure,openai])
#   Obtaining dependency information for aiofiles from https://files.pythonhosted.org/packages/a5/45/30bb92d442636f570cb5651bc661f52b610e2eec3f891a5dc3a4c3667db0/aiofiles-24.1.0-py3-none-any.whl.metadata
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting openai>=1.93 (from autogen-ext[azure,openai])
#   Obtaining dependency information for openai>=1.93 from https://files.pythonhosted.org/packages/69/41/86ddc9cdd885acc02ee50ec24ea1c5e324eea0c7a471ee841a7088653558/openai-2.0.0-py3-none-any.whl.metadata
#   Downloading openai-2.0.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken>=0.8.0 (from autogen-ext[azure,openai])
#   Obtaining dependency information for tiktoken>=0.8.0 from https://files.pythonhosted.org/packages/4f/cf/5f02bfefffdc6b54e5094d2897bc80efd43050e5b09b576fd85936ee54bf/tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting isodate>=0.6.1 (from azure-ai-inference>=1.0.0b9->autogen-ext[azure,openai])
#   Obtaining dependency information for isodate>=0.6.1 from https://files.pythonhosted.org/packages/15/aa/0aca39a37d3c7eb941ba736ede56d689e7be91cab5d9ca846bde3999eba6/isodate-0.7.2-py3-none-any.whl.metadata
#   Using cached isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai])
#   Obtaining dependency information for azure-storage-blob>=12.15.0 from https://files.pythonhosted.org/packages/5b/64/63dbfdd83b31200ac58820a7951ddfdeed1fbee9285b0f3eae12d1357155/azure_storage_blob-12.26.0-py3-none-any.whl.metadata
#   Using cached azure_storage_blob-12.26.0-py3-none-any.whl.metadata (26 kB)
# Collecting azure-ai-agents>=1.2.0b3 (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai])
#   Obtaining dependency information for azure-ai-agents>=1.2.0b3 from https://files.pythonhosted.org/packages/6d/6d/15070d23d7a94833a210da09d5d7ed3c24838bb84f0463895e5d159f1695/azure_ai_agents-1.2.0b5-py3-none-any.whl.metadata
#   Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl.metadata (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 3.5 MB/s eta 0:00:00
# Collecting requests>=2.21.0 (from azure-core->autogen-ext[azure,openai])
#   Obtaining dependency information for requests>=2.21.0 from https://files.pythonhosted.org/packages/1e/db/4254e3eabe8020b458f1a747140d32277ec7a271daf1d235b70dc0b4e6e3/requests-2.32.5-py3-none-any.whl.metadata
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.11.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,openai]) (1.17.0)
# Collecting azure-common>=1.1 (from azure-search-documents>=11.4.0->autogen-ext[azure,openai])
#   Obtaining dependency information for azure-common>=1.1 from https://files.pythonhosted.org/packages/62/55/7f118b9c1b23ec15ca05d15a578d8207aa1706bc6f7c87218efffbbf875d/azure_common-1.1.28-py2.py3-none-any.whl.metadata
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for anyio<5,>=3.5.0 from https://files.pythonhosted.org/packages/15/b3/9b1a8074496371342ec1e796a96f99c82c945a339cd81a8e73de28b4cf9e/anyio-4.11.0-py3-none-any.whl.metadata
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/fe/82/15514244e03b9e71e086bbe2a6de3e4616b48f07d5f834200c873956fb8c/jiter-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached jiter-0.11.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for sniffio from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.34.1->autogen-core)
#   Obtaining dependency information for importlib-metadata<8.8.0,>=6.0 from https://files.pythonhosted.org/packages/20/b0/36bd937216ec521246249be3bf9855081de4c5e06a0c9b4219dbeda50373/importlib_metadata-8.7.0-py3-none-any.whl.metadata
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.10.0->autogen-core)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3.0.0,>=2.10.0->autogen-core)
#   Obtaining dependency information for pydantic-core==2.33.2 from https://files.pythonhosted.org/packages/a1/02/6224312aacb3c8ecbaa959897af57181fb6cf3a3d7917fd44d0f2917e6f2/pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.10.0->autogen-core)
#   Obtaining dependency information for typing-inspection>=0.4.0 from https://files.pythonhosted.org/packages/17/69/cd203477f944c353c31bade965f880aa1061fd6bf05ded0726ca845b6ff7/typing_inspection-0.4.1-py3-none-any.whl.metadata
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting regex>=2022.1.18 (from tiktoken>=0.8.0->autogen-ext[azure,openai])
#   Obtaining dependency information for regex>=2022.1.18 from https://files.pythonhosted.org/packages/bb/3b/ff80886089eb5dcf7e0d2040d9aaed539e25a94300403814bb24cc775058/regex-2025.9.18-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached regex-2025.9.18-cp312-cp312-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting cryptography>=2.5 (from azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for cryptography>=2.5 from https://files.pythonhosted.org/packages/4c/8c/44ee01267ec01e26e43ebfdae3f120ec2312aa72fa4c0507ebe41a26739f/cryptography-46.0.1-cp311-abi3-macosx_10_9_universal2.whl.metadata
#   Using cached cryptography-46.0.1-cp311-abi3-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for msal>=1.30.0 from https://files.pythonhosted.org/packages/c2/dc/18d48843499e278538890dc709e9ee3dea8375f8be8e82682851df1b48b5/msal-1.34.0-py3-none-any.whl.metadata
#   Downloading msal-1.34.0-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for msal-extensions>=1.2.0 from https://files.pythonhosted.org/packages/5e/75/bd9b7bb966668920f06b200e84454c8f3566b102183bc55c5473d96cb2b9/msal_extensions-1.3.1-py3-none-any.whl.metadata
#   Using cached msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for idna>=2.8 from https://files.pythonhosted.org/packages/76/c6/c88e154df9c4e1a2a66ccf0005a88dfb2650c1dffb6f5ce603dfbd452ce3/idna-3.10-py3-none-any.whl.metadata
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting cffi>=2.0.0 (from cryptography>=2.5->azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for cffi>=2.0.0 from https://files.pythonhosted.org/packages/df/a2/781b623f57358e360d62cdd7a8c681f074a71d445418a776eef0aadb4ab4/cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata
#   Using cached cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/e5/48/1549795ba7742c948d2ad169c1c8cdbae65bc450d6cd753d124b17c8cd32/certifi-2025.8.3-py3-none-any.whl.metadata
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/7e/f5/f66802a942d491edb555dd61e3a9961140fd64c90bce1eafd741609d334d/httpcore-1.0.9-py3-none-any.whl.metadata
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai])
#   Obtaining dependency information for h11>=0.16 from https://files.pythonhosted.org/packages/04/4b/29cac41a4d98d144bf5f6d33995617b185d14b22401f75ca86f384e87ff1/h11-0.16.0-py3-none-any.whl.metadata
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core)
#   Obtaining dependency information for zipp>=3.20 from https://files.pythonhosted.org/packages/2e/54/647ade08bf0db230bfea292f893923872fd20be6ac6f53b2b936ba839d75/zipp-3.23.0-py3-none-any.whl.metadata
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0 (from msal>=1.30.0->azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for PyJWT[crypto]<3,>=1.0.0 from https://files.pythonhosted.org/packages/61/ad/689f02752eeec26aed679477e80e632ef1b682313be70793d798c1d5fc8f/PyJWT-2.10.1-py3-none-any.whl.metadata
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.21.0->azure-core->autogen-ext[azure,openai])
#   Obtaining dependency information for charset_normalizer<4,>=2 from https://files.pythonhosted.org/packages/e9/5e/14c94999e418d9b87682734589404a25854d5f5d0408df68bc15b6ff54bb/charset_normalizer-3.4.3-cp312-cp312-macosx_10_13_universal2.whl.metadata
#   Using cached charset_normalizer-3.4.3-cp312-cp312-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.21.0->azure-core->autogen-ext[azure,openai])
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a7/c2/fe1e52489ae3122415c51f387e221dd0773709bad6c6cdaa599e8a2c5185/urllib3-2.5.0-py3-none-any.whl.metadata
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=2.5->azure-identity->autogen-ext[azure,openai])
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/a0/e3/59cd50310fc9b59512193629e1984c1f95e5c8ae6e5d8c69532ccc65a7fe/pycparser-2.23-py3-none-any.whl.metadata
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading autogen_core-0.7.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.9/101.9 kB 6.0 MB/s eta 0:00:00
# Downloading autogen_agentchat-0.7.5-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.3/119.3 kB 9.3 MB/s eta 0:00:00
# Using cached azure_ai_inference-1.0.0b9-py3-none-any.whl (124 kB)
# Using cached azure_ai_projects-1.1.0b4-py3-none-any.whl (126 kB)
# Using cached azure_core-1.35.1-py3-none-any.whl (211 kB)
# Using cached azure_search_documents-11.5.3-py3-none-any.whl (298 kB)
# Using cached jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading openai-2.0.0-py3-none-any.whl (955 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.5/955.5 kB 22.7 MB/s eta 0:00:0000:01
# Using cached opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Using cached pillow-11.3.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
# Using cached protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
# Using cached pydantic-2.11.9-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp312-cp312-macosx_11_0_arm64.whl (1.8 MB)
# Using cached tiktoken-0.11.0-cp312-cp312-macosx_11_0_arm64.whl (996 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading autogen_ext-0.7.5-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.4/331.4 kB 20.7 MB/s eta 0:00:00
# Using cached azure_identity-1.25.0-py3-none-any.whl (190 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 14.7 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.2.0b5-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.9/217.9 kB 14.8 MB/s eta 0:00:00
# Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Using cached azure_storage_blob-12.26.0-py3-none-any.whl (412 kB)
# Using cached cryptography-46.0.1-cp311-abi3-macosx_10_9_universal2.whl (7.3 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached isodate-0.7.2-py3-none-any.whl (22 kB)
# Using cached jiter-0.11.0-cp312-cp312-macosx_11_0_arm64.whl (316 kB)
# Downloading msal-1.34.0-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.2 MB/s eta 0:00:00
# Using cached msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Using cached regex-2025.9.18-cp312-cp312-macosx_11_0_arm64.whl (287 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Using cached cffi-2.0.0-cp312-cp312-macosx_11_0_arm64.whl (181 kB)
# Using cached charset_normalizer-3.4.3-cp312-cp312-macosx_10_13_universal2.whl (205 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Installing collected packages: azure-common, zipp, urllib3, typing-extensions, tqdm, sniffio, regex, PyJWT, pycparser, protobuf, pillow, jsonref, jiter, isodate, idna, h11, distro, charset_normalizer, certifi, annotated-types, aiofiles, typing-inspection, requests, pydantic-core, importlib-metadata, httpcore, cffi, anyio, tiktoken, pydantic, opentelemetry-api, httpx, cryptography, azure-core, openai, azure-storage-blob, azure-search-documents, azure-ai-inference, azure-ai-agents, autogen-core, msal, azure-ai-projects, autogen-ext, autogen-agentchat, msal-extensions, azure-identity
# Successfully installed PyJWT-2.10.1 aiofiles-24.1.0 annotated-types-0.7.0 anyio-4.11.0 autogen-agentchat-0.7.5 autogen-core-0.7.5 autogen-ext-0.7.5 azure-ai-agents-1.2.0b5 azure-ai-inference-1.0.0b9 azure-ai-projects-1.1.0b4 azure-common-1.1.28 azure-core-1.35.1 azure-identity-1.25.0 azure-search-documents-11.5.3 azure-storage-blob-12.26.0 certifi-2025.8.3 cffi-2.0.0 charset_normalizer-3.4.3 cryptography-46.0.1 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.10 importlib-metadata-8.7.0 isodate-0.7.2 jiter-0.11.0 jsonref-1.1.0 msal-1.34.0 msal-extensions-1.3.1 openai-2.0.0 opentelemetry-api-1.37.0 pillow-11.3.0 protobuf-5.29.5 pycparser-2.23 pydantic-2.11.9 pydantic-core-2.33.2 regex-2025.9.18 requests-2.32.5 sniffio-1.3.1 tiktoken-0.11.0 tqdm-4.67.1 typing-extensions-4.15.0 typing-inspection-0.4.1 urllib3-2.5.0 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_agentchat.conditions import TextMentionTermination
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %%
# %pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Obtaining dependency information for python-dotenv from https://files.pythonhosted.org/packages/5f/ed/539768cf28c661b5b068d66d96a2f155c4971a5d55684a514c1a0e0dec2f/python_dotenv-1.1.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.1.1
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from dotenv import load_dotenv

# %%
cwd = Path.cwd()
env_path = cwd.parent / ".env"
loaded = load_dotenv(env_path)

# %%
# This is the same as in L1
azure_deployment = os.getenv("AZURE_DEPLOYMENT_NAME")
api_version = "2024-12-01-preview"  # If you're using gpt-5-mini as demonstrated

# e.g. https://ccoha-mfoynknp-eastus2.cognitiveservices.azure.com/
azure_endpoint = os.getenv("AZURE_ENDPOINT")

# %% [markdown]
# ## An Example Three-Agent System Architecture
#
# Based on the suggested roles from the overview:
# - **Planner**: Decomposes the user goal into a concise, ordered plan
# - **Implementer**: Executes the steps from the plan
# - **Critic/Integrator**: Reviews output and suggests improvements or approves completion

# %%
async def setup_three_agent_system():
    """Set up the three-agent system with Planner, Implementer, and Critic roles"""
    
    # Create the Azure OpenAI client
    client = AzureOpenAIChatCompletionClient(
        azure_deployment=azure_deployment,
        model="gpt-5-mini",
        api_version=api_version,
        azure_endpoint=azure_endpoint,
        api_key=os.getenv("AZURE_SUBSCRIPTION_KEY"),
    )
    
    # Define the three agents with specific system prompts
    planner = AssistantAgent(
        name="Planner",
        model_client=client,
        system_message="""You are a task decomposition specialist. Your role is to:
        1. Break down complex user goals into clear, numbered steps
        2. Define specific inputs/outputs for each step  
        3. Provide testable acceptance criteria for each step
        4. Present plans in a structured, actionable format
        
        Always end your response with 'PLAN_COMPLETE' when finished."""
    )
    
    implementer = AssistantAgent(
        name="Implementer", 
        model_client=client,
        system_message="""You are an implementation specialist. Your role is to:
        1. Follow the Planner's steps methodically
        2. Address each step with concrete outputs/artifacts
        3. Provide detailed solutions that meet the specified criteria
        4. Ask for clarification if any step is unclear
        
        Always end your response with 'IMPLEMENTATION_COMPLETE' when finished."""
    )
    
    critic = AssistantAgent(
        name="Critic",
        model_client=client, 
        system_message="""You are a quality assurance specialist. Your role is to:
        1. Review the Implementer's work against the Planner's criteria
        2. Identify gaps, errors, or missing elements
        3. Suggest specific improvements if needed
        4. Only approve with 'APPROVED' if all criteria are fully met
        
        Be thorough but constructive in your feedback."""
    )
    
    return planner, implementer, critic

# %%
async def run_three_agent_workflow(task_description):
    """Run the three-agent workflow for a given task"""

    # Set up the agents
    planner, implementer, critic = await setup_three_agent_system()

    # Create termination condition - look for "APPROVED" in messages
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.base.html#autogen_agentchat.base.TerminationCondition
    termination = TextMentionTermination("APPROVED")

    # Create a group chat with the three agents
    # The RoundRobinGroupChat will manage turn-taking between agents
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.teams.html#autogen_agentchat.teams.RoundRobinGroupChat
    team = RoundRobinGroupChat([planner, implementer, critic], termination_condition=termination)

    # Run the workflow
    print("Starting three-agent workflow...")
    print("=" * 60)

    # Start the conversation
    result = await Console(
        team.run_stream(task=task_description)
    )

    return result

# %% [markdown]
# ## Example Task 1: Analytical Task
#
# Test the three-agent system with a small example analytical task.

# %%
# Test Task 1: Compare sorting algorithms
analytical_task = """
Compare the pros and cons of Quick Sort vs Merge Sort algorithms. 
Provide a structured analysis that includes:
- Time and space complexity for both
- Best/worst case scenarios  
- Practical use cases for each
- A final recommendation with justification
"""

# Uncomment to run when ready:
await run_three_agent_workflow(analytical_task)
# Out:
# Starting three-agent workflow...
# ============================================================
# ---------- TextMessage (user) ----------
#
# Compare the pros and cons of Quick Sort vs Merge Sort algorithms.
# Provide a structured analysis that includes:
# - Time and space complexity for both
# - Best/worst case scenarios
# - Practical use cases for each
# - A final recommendation with justification
#
# ---------- TextMessage (Planner) ----------
# 1) Step 1 — Define scope and assumptions
# - Input: user request to compare Quick Sort and Merge Sort; assumed context: common in-memory array implementations unless otherwise noted; typical recursive implementations; interest in algorithmic properties and practical usage.
# - Output: explicit scope statement and assumptions that bound the comparison.
# - Acceptance criteria (testable):
#   - The response states the assumed data structures (arrays, linked lists) and implementation flavors (recursive, in-place QuickSort, top-down MergeSort).
#   - Any special variants (randomized QuickSort, bottom-up MergeSort, stable/in-place variants) are noted as exceptions.
#
# Content for Step 1:
# - Scope: Comparison focuses on standard implementations:
#   - Quick Sort: in-place, recursive, array-based pivot-partitioning (Lomuto/Hoare), can be randomized.
#   - Merge Sort: top-down recursive or bottom-up iterative on arrays; classic Merge uses O(n) auxiliary array; MergeSort on linked lists can be done with O(1) extra memory for node pointers.
# - Assumptions: comparisons use Big-O for n items; consider time, space, stability, cache behavior, parallelizability, and typical constant factors.
#
# 2) Step 2 — Time and space complexity (explicit)
# - Input: definitions from Step 1.
# - Output: clear Big-O for best/average/worst time complexity and space complexity for both algorithms, with short explanation.
# - Acceptance criteria:
#   - Contains best, average, worst time complexity for QuickSort and MergeSort.
#   - Contains space complexity (auxiliary + recursion) for standard implementations and notes special cases (linked-list MergeSort, in-place QuickSort recursion depth, randomized QuickSort).
#   - Short explanation for why each complexity arises.
#
# Content for Step 2:
# - Quick Sort (standard in-place, array):
#   - Time:
#     - Best case: O(n log n) — balanced partitions.
#     - Average case: O(n log n) — expected when pivots split reasonably.
#     - Worst case: O(n^2) — highly unbalanced partitions (e.g., sorted input with poor pivot like first element).
#     - Randomized pivot selection reduces probability of worst-case and gives expected O(n log n).
#   - Space:
#     - Auxiliary: O(1) extra for partitioning (in-place).
#     - Recursion stack: O(log n) average (balanced), O(n) worst (degenerate recursion).
# - Merge Sort (classic top-down on arrays):
#   - Time:
#     - Best/average/worst: all O(n log n) — divide-and-conquer merging dominates consistently.
#   - Space:
#     - Auxiliary: O(n) extra array for merging in typical array implementations.
#     - Recursion stack: O(log n).
#   - Special cases:
#     - MergeSort on linked lists can be done with O(1) auxiliary space (reusing pointers) and still O(n log n) time.
#     - There are in-place (O(1) aux) merge algorithms but they are complex and have worse constants.
#
# 3) Step 3 — Pros and cons (detailed, testable)
# - Input: complexities and assumptions from previous steps.
# - Output: enumerated pros and cons for each algorithm, covering stability, in-place property, average speed and constants, cache behavior, parallelizability, and robustness.
# - Acceptance criteria:
#   - At least 5 pros and 5 cons combined across both algorithms (covering stability, space, speed, worst-case behavior, and parallelization).
#   - Each pro/con is linked to a technical reason (e.g., cache locality leads to smaller constants).
#
# Content for Step 3:
# - Quick Sort — Pros:
#   1. Fast in practice for in-memory arrays: good cache locality and small inner loops give low constant factors.
#   2. In-place partitioning: requires only O(1) extra array space (excluding stack).
#   3. Low average recursion depth: O(log n) on average.
#   4. Simple randomized pivot makes worst-case extremely unlikely.
#   5. Works well with small partitions (can switch to insertion sort for small n).
# - Quick Sort — Cons:
#   1. Worst-case O(n^2) time for poor pivot choices (unless mitigated by randomization or introsort).
#   2. Not stable by default (equal elements can be reordered).
#   3. Recursion depth can be O(n) in degenerate cases; may need tail recursion elimination or explicit stack.
#   4. Pivot selection overhead or pathological input can degrade performance.
#   5. Not ideal for external sorting (requires random access and has poor behavior with large data on disk).
# - Merge Sort — Pros:
#   1. Guaranteed O(n log n) time in all cases — predictable performance.
#   2. Stable by default (merge preserves order of equal elements).
#   3. Easy to parallelize: independent subproblems and parallel merges possible.
#   4. Good for external sorting / large data sets: sequential reads/writes are efficient.
#   5. Simple and reliable for linked lists (O(1) extra space when merging pointers).
# - Merge Sort — Cons:
#   1. Requires O(n) extra memory for arrays (typical implementation); higher memory footprint.
#   2. Higher constant factors and less cache-friendly than QuickSort in array in-memory scenarios.
#   3. More copying/temporary arrays increase memory bandwidth usage.
#   4. In-place variants exist but are complex and slower in practice.
#   5. For small arrays, less efficient than optimized QuickSort + insertion sort hybrids.
#
# 4) Step 4 — Practical use cases and guidance
# - Input: pros/cons and complexities.
# - Output: concrete scenarios recommending one algorithm over the other, and alternatives/mitigations.
# - Acceptance criteria:
#   - Provides at least three distinct practical use cases where QuickSort is preferable and three where MergeSort is preferable.
#   - Mentions practical mitigations (randomized pivot, introsort, stable variants, linked-list merge).
#   - Notes alternative hybrid algorithms (e.g., TimSort, introsort) where relevant.
#
# Content for Step 4:
# - When to choose Quick Sort:
#   1. In-memory array sorting where average speed and cache locality matter (desktop/server sorting of arrays).
#   2. Memory-constrained contexts where O(1) auxiliary array is important.
#   3. Performance-critical code where low constant factors are valued and inputs are not adversarial (or pivot randomization/median-of-three is used).
# - When to choose Merge Sort:
#   1. Need for stable sort (e.g., multi-key sorting where stability preserves earlier ordering).
#   2. External sorting / very large datasets that don’t fit in memory (merge phases read/write sequentially).
#   3. Parallel sorting implementations where predictable divide-and-conquer and merging are easy to distribute.
#   4. Linked lists: MergeSort is ideal because it can be done in-place with O(1) aux memory and O(n log n) time.
# - Practical mitigations and hybrids:
#   - Use randomized QuickSort or median-of-three pivot to reduce risk of worst-case.
#   - Use introsort (QuickSort with fallback to HeapSort) to guarantee O(n log n) worst-case while retaining QuickSort’s speed — e.g., C++ std::sort.
#   - For real-world general-purpose languages, prefer library sorts: TimSort (Python, Java for object arrays) is stable and tuned for partially ordered inputs.
#   - For stable array sorts that avoid O(n) extra memory, consider stable in-place algorithms or use extra index arrays depending on constraints.
#
# 5) Step 5 — Final recommendation with justification
# - Input: all previous steps.
# - Output: a clear final recommendation specifying which algorithm to prefer in common scenarios, and when to pick the other; include fallback strategies.
# - Acceptance criteria:
#   - Provides a concise recommended default for typical use (in-memory arrays).
#   - Lists specific conditions that would change the recommendation (need for stability, external data, worst-case adversarial inputs).
#   - Recommends concrete mitigations/hybrids (randomized pivot, introsort, MergeSort for linked lists/external).
#
# Content for Step 5 — Recommendation:
# - Default recommendation for general-purpose in-memory array sorting:
#   - Prefer QuickSort (or its robust variant, introsort) for raw in-memory array sorting because of its excellent average-case performance, cache efficiency, and low extra memory usage. In production code, use a well-tested library implementation (std::sort uses introsort) which gives QuickSort-like speed with worst-case safeguards.
# - When to choose MergeSort instead:
#   - Choose MergeSort when stability is required, when sorting linked lists, when working with data that doesn't fit in memory (external/parallel merges), or when predictable worst-case time guarantees are necessary and you cannot/ do not want to use introsort.
# - Justification summary:
#   - QuickSort: better practical throughput for arrays due to cache locality and small constants; in-place reduces memory footprint; randomized or introsort variants mitigate worst-case.
#   - MergeSort: stronger theoretical guarantees and stability; superior for external and parallel sorting and linked lists; predictable performance and simpler parallelization.
# - Practical final note:
#   - Use the language/library default unless you have specific constraints. If you implement yourself, use randomized pivot or introsort for QuickSort, or use MergeSort when stability and predictable worst-case are priorities.
#
# Acceptance checklist (overall)
# - The plan specified scope and assumptions. (Step 1)
# - Time and space complexity for both algorithms included with best/avg/worst. (Step 2)
# - Pros and cons explicitly listed. (Step 3)
# - Practical use cases and mitigations/hybrids listed. (Step 4)
# - Final recommendation with clear justification and when to deviate. (Step 5)
#
# PLAN_COMPLETE
# ---------- TextMessage (Implementer) ----------
# Step 1 — Scope and assumptions
# - Scope: comparison focuses on commonly used, standard implementations:
#   - Quick Sort: in-place, recursive, array-based pivot partitioning (Hoare or Lomuto), with notes on randomized pivot and median-of-three; excludes exotic in-place stable QuickSort variants.
#   - Merge Sort: classic top-down recursive and bottom-up iterative implementations for arrays that use an auxiliary O(n) buffer for merging; also notes the standard linked-list MergeSort which uses pointer re-linking and can avoid O(n) buffer.
# - Data structures assumed: primarily arrays (random-access), with explicit mention of linked lists where MergeSort behaves differently.
# - Implementation flavors noted: recursive QuickSort and MergeSort; bottom-up MergeSort; randomized QuickSort; introsort (QuickSort with fallback to HeapSort) and TimSort mentioned as practical hybrids.
# - Metrics considered: time and space complexity, best/average/worst cases, stability, in-place property, cache behavior, parallelizability, typical constant factors.
# - Assumptions: n = number of items to sort; Big-O used for complexity; “space” means additional (auxiliary) memory beyond input plus recursion stack unless otherwise noted.
#
# Step 2 — Time and space complexity (explicit)
# - Quick Sort (standard in-place array implementation)
#   - Time complexity:
#     - Best case: O(n log n) — pivots split the array into balanced partitions (≈ halves) at each level.
#     - Average case: O(n log n) — expected over random inputs or randomized pivot choice.
#     - Worst case: O(n^2) — highly unbalanced partitions (e.g., always picking smallest/largest pivot on already sorted data if pivot scheme is poor).
#   - Space complexity:
#     - Auxiliary (non-recursive): O(1) for in-place partitioning.
#     - Recursion stack: O(log n) average (balanced); O(n) worst (degenerate recursion).
#   - Notes: randomized pivot selection makes the bad worst-case extremely unlikely in expectation.
#
# - Merge Sort (classic array top-down or bottom-up)
#   - Time complexity:
#     - Best case: O(n log n) — splitting and merging costs dominate; even if partially ordered, classic MergeSort still performs O(n log n) comparisons (although some implementations can detect runs).
#     - Average case: O(n log n).
#     - Worst case: O(n log n) — guaranteed.
#   - Space complexity:
#     - Auxiliary: O(n) extra array for merging in typical array-based implementations.
#     - Recursion stack: O(log n) for top-down recursion (bottom-up iterative version has O(1) stack).
#   - Special cases:
#     - MergeSort on singly/doubly linked lists: O(1) auxiliary memory (relinking nodes) and O(n log n) time.
#     - In-place array merge (O(1) extra) exists but is complex and has high constants; not usually used in practice.
#
# Step 3 — Pros and cons (enumerated)
# - Quick Sort — Pros
#   1. Fast in practice for in-memory arrays: excellent cache locality and very tight inner loops give low constant factors.
#   2. In-place: requires only O(1) auxiliary array storage (excluding recursion stack).
#   3. Small average recursion depth: O(log n) average stack usage.
#   4. Simple optimizations: median-of-three, random pivot, and switching to insertion sort for small partitions dramatically improve real-world performance.
#   5. Good for CPU-bound single-machine sorting of arrays where memory overhead is constrained.
#
# - Quick Sort — Cons
#   1. Worst-case O(n^2) time for poor pivot choices or adversarial input (unless mitigated).
#   2. Not stable by default — equal elements may be reordered.
#   3. Recursion depth can become O(n) in worst-case; requires care (tail recursion elimination, stack depth limits, or iterative implementation).
#   4. Less suitable for external sorting (requires random access and not optimized for sequential I/O).
#   5. Performance can degrade on certain data distributions without pivot strategy adjustments.
#
# - Merge Sort — Pros
#   1. Guaranteed O(n log n) time in all cases — predictable worst-case behavior.
#   2. Stable by default — merging preserves input order among equal keys.
#   3. Easy to parallelize: subproblems and merges can be distributed across processors cleanly.
#   4. Excellent for external sorting and large datasets: merge phases are sequential I/O friendly (good for tapes/disks).
#   5. Ideal for linked lists: in-place merging using pointer updates gives O(1) extra memory and O(n log n) time.
#
# - Merge Sort — Cons
#   1. Additional memory: typical array-based MergeSort needs O(n) extra space, increasing memory footprint.
#   2. Higher constant factors and less cache-friendly for arrays compared with in-place QuickSort (more copying).
#   3. More memory bandwidth used (copies between source and auxiliary arrays).
#   4. In-place array merge algorithms exist but are complex and often slower in practice.
#   5. For small arrays, MergeSort is usually slower than optimized QuickSort + insertion sort hybrids.
#
# Step 4 — Practical use cases and guidance
# - When to choose Quick Sort (practical scenarios)
#   1. General-purpose in-memory array sorting where raw throughput (average-case speed) matters and memory is limited.
#   2. Performance-critical code on typical hardware where cache locality and low allocations give better wall-clock performance.
#   3. Environments where you can apply pivot improvements (randomization or introsort) to avoid pathological worst-cases.
#   4. Sorting primitive types (integers/floats) in place where stability is not required.
#   5. Resource-constrained systems where O(1) extra memory is important.
#
# - When to choose Merge Sort (practical scenarios)
#   1. When stability is required (e.g., multi-key sorts where earlier keys must be preserved).
#   2. External sorting or very large datasets that exceed RAM — external merge sort is standard because of sequential I/O patterns.
#   3. Parallel/distributed sorting tasks — merging and recursive subdivisions map well to parallel compute.
#   4. Sorting linked lists — MergeSort is the natural choice (no extra array needed).
#   5. When predictable worst-case time guarantees are required and you cannot or don’t want to use hybrid algorithms.
#
# - Practical mitigations, hybrids, and alternatives
#   - Randomized QuickSort or median-of-three pivot reduces chance of worst-case; also combine with switching to insertion sort on small partitions.
#   - Introsort (QuickSort that falls back to HeapSort when recursion gets too deep) guarantees O(n log n) worst-case while preserving QuickSort-like speed — used by C++ std::sort.
#   - TimSort (used in Python and Java for object arrays) is a stable, adaptive algorithm combining merge ideas and run detection — excellent for real-world data with existing order.
#   - For arrays requiring stability but wanting lower extra memory, consider external strategies, index-based stable sorts (sort indices instead of objects), or language/library-provided stable sorts.
#   - For linked lists or pointer-based sequences, use MergeSort to avoid additional memory.
#
# Step 5 — Final recommendation with justification
# - Default recommendation for typical in-memory array sorting:
#   - Use a QuickSort-based approach (preferably a robust variant such as introsort) or use the language/library default sort. Rationale: QuickSort (and introsort) provide superior practical throughput on arrays because of cache locality, low overhead, and in-place operation; introsort adds a worst-case guarantee without sacrificing typical performance. In real projects, rely on well-tested std library implementations (e.g., C++ std::sort) or TimSort (Python/Java) rather than hand-rolling your own.
# - When to pick MergeSort instead:
#   - Choose MergeSort when you need stability, are sorting linked lists, are implementing external or parallel sorts, or require guaranteed O(n log n) worst-case behavior and either cannot use introsort or want a stable guarantee. MergeSort is also appropriate when memory bandwidth and sequential I/O are more important than in-memory cache locality.
# - Concrete fallback strategies:
#   - If you need both speed and worst-case guarantees: use introsort (QuickSort + HeapSort fallback).
#   - If you need stability on arrays and good real-world performance: use TimSort or a stable MergeSort implemented carefully (accepting O(n) extra memory or using run-aware techniques).
#   - For external sorting of huge datasets: use k-way merge algorithms based on MergeSort principles.
#
# Concise justification summary
# - QuickSort (or introsort) for in-memory arrays gives the best real-world performance in most cases due to cache friendliness and low extra memory; use pivot randomization/median-of-three and hybridization to mitigate worst-case risks.
# - MergeSort for stability, external or parallel workloads, linked lists, or when worst-case predictability is essential.
#
# Checklist (this response meets the Planner acceptance criteria)
# - Scope and assumptions stated (arrays/linked lists, standard flavors, variants noted).
# - Time and space complexity for both algorithms provided with best/avg/worst and brief explanations.
# - Pros and cons enumerated covering stability, space, speed, worst-case behavior, and parallelization.
# - Practical use cases and mitigations/hybrids listed (QuickSort, MergeSort, introsort, TimSort, linked-list Merge).
# - Final recommendation given with clear conditions for deviating and fallback strategies.
#
# If you want, I can:
# - Show short pseudo-code snippets for each algorithm (recursive QuickSort and top-down MergeSort).
# - Provide benchmark guidance (microbenchmarks to compare on your target hardware and data distributions).
# Which would you like next?
#
# IMPLEMENTATION_COMPLETE
# ---------- TextMessage (Critic) ----------
# Review summary
#
# The Implementer's response meets the Planner's acceptance criteria: scope and assumptions are explicit, time/space complexities (best/avg/worst) are stated with explanations, pros and cons are enumerated and linked to technical reasons, practical use cases and mitigations/hybrids are provided, and a clear final recommendation with conditions and fallbacks is given.
#
# What was done well
# - Scope & assumptions: Clearly states array and linked-list contexts and the implementation flavors (top-down/bottom-up merge, in-place QuickSort, randomized/median-of-three, introsort, TimSort).
# - Complexity: Gives best/average/worst time complexities and space (auxiliary + recursion) for both algorithms, plus special cases (linked-list merge, in-place merge caveats).
# - Pros/cons: Detailed, technically justified lists for both algorithms covering stability, memory, cache behavior, worst-case, and parallelization.
# - Use cases & mitigations: Provides multiple concrete scenarios for choosing each algorithm and lists practical hybrids (randomized QuickSort, introsort, TimSort) and other mitigations.
# - Recommendation: Concise default recommendation (QuickSort/Introsort for in-memory arrays), and explicit situations where MergeSort is preferable, with fallback strategies.
#
# Minor suggestions to improve thoroughness (optional)
# - Add brief pseudocode snippets (the Implementer offered these); they would help readers who want concrete algorithm outlines.
# - Note that some adaptive MergeSort implementations (and TimSort) detect runs and can approach O(n) on nearly-sorted data — the Implementer did mention run-detection for TimSort but could explicitly state the potential best-case improvement for such adaptive merges.
# - Mention that stable QuickSort variants exist (e.g., by pairing keys with indices or using stable partition schemes) but usually incur extra memory or cost — the Implementer touched on instability but could briefly note the trade-offs for making QuickSort stable.
# - For clarity: indicate that C++ std::stable_sort typically uses a mergesort-like stable algorithm (with O(n) extra memory), while std::sort uses introsort; this helps map recommendations to common library behavior.
#
# Decision
# All Planner acceptance criteria are fully met and content is accurate and comprehensive. APPROVED
# TaskResult(messages=[TextMessage(id='744b88ed-f678-43ee-959c-a8e634a84a50', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 9, 30, 22, 25, 56, 945373, tzinfo=datetime.timezone.utc), content='\nCompare the pros and cons of Quick Sort vs Merge Sort algorithms. \nProvide a structured analysis that includes:\n- Time and space complexity for both\n- Best/worst case scenarios  \n- Practical use cases for each\n- A final recommendation with justification\n', type='TextMessage'), TextMessage(id='ce3c68ca-4d5a-4aad-b15c-515741392ced', source='Planner', models_usage=RequestUsage(prompt_tokens=141, completion_tokens=2815), metadata={}, created_at=datetime.datetime(2025, 9, 30, 22, 26, 23, 178686, tzinfo=datetime.timezone.utc), content="1) Step 1 — Define scope and assumptions\n- Input: user request to compare Quick Sort and Merge Sort; assumed context: common in-memory array implementations unless otherwise noted; typical recursive implementations; interest in algorithmic properties and practical usage.\n- Output: explicit scope statement and assumptions that bound the comparison.\n- Acceptance criteria (testable):\n  - The response states the assumed data structures (arrays, linked lists) and implementation flavors (recursive, in-place QuickSort, top-down MergeSort).\n  - Any special variants (randomized QuickSort, bottom-up MergeSort, stable/in-place variants) are noted as exceptions.\n\nContent for Step 1:\n- Scope: Comparison focuses on standard implementations:\n  - Quick Sort: in-place, recursive, array-based pivot-partitioning (Lomuto/Hoare), can be randomized.\n  - Merge Sort: top-down recursive or bottom-up iterative on arrays; classic Merge uses O(n) auxiliary array; MergeSort on linked lists can be done with O(1) extra memory for node pointers.\n- Assumptions: comparisons use Big-O for n items; consider time, space, stability, cache behavior, parallelizability, and typical constant factors.\n\n2) Step 2 — Time and space complexity (explicit)\n- Input: definitions from Step 1.\n- Output: clear Big-O for best/average/worst time complexity and space complexity for both algorithms, with short explanation.\n- Acceptance criteria:\n  - Contains best, average, worst time complexity for QuickSort and MergeSort.\n  - Contains space complexity (auxiliary + recursion) for standard implementations and notes special cases (linked-list MergeSort, in-place QuickSort recursion depth, randomized QuickSort).\n  - Short explanation for why each complexity arises.\n\nContent for Step 2:\n- Quick Sort (standard in-place, array):\n  - Time:\n    - Best case: O(n log n) — balanced partitions.\n    - Average case: O(n log n) — expected when pivots split reasonably.\n    - Worst case: O(n^2) — highly unbalanced partitions (e.g., sorted input with poor pivot like first element).\n    - Randomized pivot selection reduces probability of worst-case and gives expected O(n log n).\n  - Space:\n    - Auxiliary: O(1) extra for partitioning (in-place).\n    - Recursion stack: O(log n) average (balanced), O(n) worst (degenerate recursion).\n- Merge Sort (classic top-down on arrays):\n  - Time:\n    - Best/average/worst: all O(n log n) — divide-and-conquer merging dominates consistently.\n  - Space:\n    - Auxiliary: O(n) extra array for merging in typical array implementations.\n    - Recursion stack: O(log n).\n  - Special cases:\n    - MergeSort on linked lists can be done with O(1) auxiliary space (reusing pointers) and still O(n log n) time.\n    - There are in-place (O(1) aux) merge algorithms but they are complex and have worse constants.\n\n3) Step 3 — Pros and cons (detailed, testable)\n- Input: complexities and assumptions from previous steps.\n- Output: enumerated pros and cons for each algorithm, covering stability, in-place property, average speed and constants, cache behavior, parallelizability, and robustness.\n- Acceptance criteria:\n  - At least 5 pros and 5 cons combined across both algorithms (covering stabili ...

# %% [markdown]
# ## Example Task 2: Creative Task
#
# Test the three-agent system with a creative writing task.

# %%
# Test Task 2: Creative writing with constraints  
creative_task = """
Write a 150-word summary of the benefits of renewable energy that:
- Uses exactly 3 specific statistics or data points
- Includes at least 2 types of renewable energy sources
- Has a compelling call-to-action in the final sentence
- Maintains an optimistic but factual tone throughout
"""

# Uncomment to run when ready:
# await run_three_agent_workflow(creative_task)

# %% [markdown]
# ## Your Task
#
# Write your own task for the planner-implementer-critic system

# %%
your_task = """
Your task description here.
"""
# Uncomment to run when ready:
# await run_three_agent_workflow(your_task)

# %% [markdown]
# NOTE: You'll notice that the output might contain duplicated text, that is because `Console` prints when a text message is sent and received.

# %% [markdown]
# ## Reflection & Analysis

# %% [markdown]
# ### What worked well?
# [Reflect on where the three-agent pattern performed effectively]
#
# ### What struggled?
# [Note areas where the pattern faced challenges or limitations]
#
# ### Potential improvements:
# [Consider what changes could make the system more effective]
#
# ### Tool integration:
# [Optional: Discuss how adding tools (like a calculator function) might improve the system]

# %% [markdown]
# # Optional Extensions

# %% [markdown]
# ## Adding Tools (Optional Challenge)
#
# Consider adding a simple tool function that agents can use, such as a calculator or text analyzer.

# %%
# Example tool function (uncomment and modify as needed)
# def calculator(expression: str) -> float:
#     """Simple calculator tool for basic mathematical operations"""
#     try:
#         # WARNING: eval() should not be used in production - use a proper math parser
#         result = eval(expression)
#         return result
#     except Exception as e:
#         return f"Error: {str(e)}"

# To integrate tools with AutoGen agents, you would typically:
# 1. Define tool schemas following MCP-like patterns
# 2. Register tools with specific agents  
# 3. Update system prompts to mention available tools
# 4. Handle tool calls in the conversation flow

# %% [markdown]
# # Summary and Next Steps

# %% [markdown]
# ## Key Takeaways
#
# - **Task Decomposition**: [Your insights about breaking down complex problems]
# - **Agent Design**: [What you learned about defining agent roles and responsibilities]
# - **Communication Protocols**: [Understanding of MCP and A2A interactions]
#
# ## References
#
# - [AutoGen Documentation](https://microsoft.github.io/autogen/stable/index.html)
# - [Model Context Protocol](https://modelcontextprotocol.io/docs/getting-started/intro)
# - [Agent-to-Agent Protocol](https://a2a-protocol.org/latest/)
# - L2_overview.md (Lab requirements and detailed explanations)

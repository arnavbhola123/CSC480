# %% [markdown]
# # CSC 480-F25 Lab 2: Task Decomposition, Multi‑Agent Design Patterns, and Communication Protocols

# %% [markdown]
# # Authors:

# %% [markdown]
# ***Arnav Bhola, Pranav Krishna***
#
# California Polytechnic State University, San Luis Obispo;
#
# Computer Science & Software Engineering Department

# %% [markdown]
# # Overview
#
# This lab focuses on:
# - Breaking down complex problems into smaller tasks (task decomposition)
# - Defining specialized agents with clear roles and responsibilities
# - Choosing appropriate multi-agent design patterns
# - Specifying communication protocols between agents
# - Implementing a three-agent system using AutoGen
#
# NOTE: If you already know what you're going to do for your final project, you may use this lab to make progress on it. Otherwise, treat this lab as a distinct exercise.
#
# ## Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Decompose a complex problem into a comprehensive set of constituent tasks
# - Identify and define the roles, responsibilities, and abilities of individual agents
# - Select and justify an appropriate multi-agent design pattern (Manager‑Worker, Sequential Pipeline, Collaborative Team)
# - Explain and apply foundational agent communication protocols at a high level (MCP, A2A)
# - Start thinking about the architecture of your project (agents, tasks, design pattern, and interaction protocols)

# %% [markdown]
# # Part 1: Task Decomposition and Agent Design

# %% [markdown]
# ## 1. Problem Statement & Task Decomposition
#
# **Main Problem:** This agent will solve the issue of bug fixing in code files
#
# **Task Breakdown:** List the steps and sub-tasks needed to achieve the goal:
# 1. This agent will first find the code block(s) that are associated with the bug
# 2. This agent will patch/fix the bug and provide the new code
# 3. This agent will check the code to ensure the bug is fixed and no new errors are created by this fix. If a new error is created, it will repeat step 3.
#
# Agent Exits once code is working.

# %% [markdown]
# ## 2. Agent Definition
#
# Define your primary agents with clear roles and responsibilities:
#
# ### Agent 1: Bug Context Identifier Agent
# - **Role:** Worker Agent (Finds code chunks related to bug)
# - **Responsibilities:** Finds the code chunks related to the bug in context with the whole program
# - **Inputs:** Gets user input for the code as well as the description of the bug
# - **Outputs:** Returns the code chunks related to bug
# - **Success Criteria:** Successful if the agent returns a code chunk, if no code chunk returned, then bug doesn't exist
#
# ### Agent 2: Code Fixer Agent
# - **Role:** Worker Agent (Fixes the code chunk to patch the bug)
# - **Responsibilities:** Fixes the code chunk to patch the bug
# - **Inputs:** Recieves code chunks from Agent 1
# - **Outputs:** Outputs the updated/fixed code of the whole program
# - **Success Criteria:** Successful, if the agent returns the fixed code of the whole program, failed if it doesn't output any code or other unneeded content.
#
# ### Agent 3: QA Agent
# - **Role:** Manager Agent (Quality checks the code)
# - **Responsibilities:** Quality checks the code and if any errors are found, it will return a description of the bug and provide the code chunk back to agent 2.
# - **Inputs:** Recieves the full code of the "fixed" program
# - **Outputs:** Returns the code of the whole program
# - **Success Criteria:** Successful, if the agent returns the fixed code of the whole program, failed if it doesn't output any code or other unneeded content.

# %% [markdown]
# ## 3. Design Pattern Selection
#
# **Chosen Pattern:** Sequential Pipeline
#
# **Justification:** This pattern works since this follows a pipeline-like approach where it follows a series of steps to fix the code, and at the end there could be a cyclic step which repeats until errors are caught and fixed.

# %% [markdown]
# ## 4. Communication Design
#
# ### Model Context Protocol (MCP)
# **Shared Context & Tools:** Full code base from the user input
#
# ### Agent-to-Agent (A2A) Interactions
#
# #### Interaction 1: [User] → [Agent 1]
# - **Purpose:** This sends the full program code + bug description to Agent 1
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Message structure consists of the full program code and a description of the bug
#
# #### Interaction 2: [Agent 1] → [Agent 2]
# - **Purpose:** This sends the output of Agent 1 (the detected code blocks related to the bug) to Agent 2
# - **Key Fields:** Code field + bug description message
# - **Message Format:** Message structure consists of a code field and a description of the bug
#
# #### Interaction 3: [Agent 2] → [Agent 3]
# - **Purpose:** This sends the fixed code of the whole program to the QA agent
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Full program code and a description of the bug
#
# #### Interaction 4: [Agent 3] → [Agent 2]  (OPTIONAL)
# - **Purpose:** If issues are found by QA agent, this will send any new bugs/issues detected to Agent 2 to fix
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Full program code and a description of the bug
#
# ### Exit

# %% [markdown]
# ## 5. Interaction Diagram
# ```
#                    ←    ←    ←
#                    ↓         ↑
# User → Agent 1 → Agent 2 → Agent 3 → Exit
#   ↓      ↓         ↓         ↓
#        A2A        A2A       A2A
# Msg1   Msg2       Msg3      Msg4
# ```

# %% [markdown]
# # Part 2: Three-Agent AutoGen Implementation

# %% [markdown]
# ## Environment Setup
#
# Install required packages and set up Azure OpenAI configuration.

# %%
# %pip install "autogen-core" "autogen-agentchat" "autogen-ext[openai,azure]"
# Out:
# Requirement already satisfied: autogen-core in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (0.7.5)
# Requirement already satisfied: autogen-ext[azure,openai] in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (0.7.5)
# Requirement already satisfied: jsonref~=1.1.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (1.37.0)
# Requirement already satisfied: pillow>=11.0.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (5.29.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-core) (4.15.0)
# Requirement already satisfied: azure-ai-inference>=1.0.0b9 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (1.1.0b4)
# Requirement already satisfied: azure-core in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (1.35.1)
# Requirement already satisfied: azure-identity in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (1.25.0)
# Requirement already satisfied: azure-search-documents>=11.4.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (11.5.3)
# Requirement already satisfied: aiofiles in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (2.0.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from autogen-ext[azure,openai]) (0.11.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-ai-inference>=1.0.0b9->autogen-ext[azure,openai]) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (12.26.0)
# Requirement already satisfied: azure-ai-agents>=1.2.0b3 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (1.2.0b5)
# Requirement already satisfied: requests>=2.21.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,openai]) (2.32.5)
# Requirement already satisfied: six>=1.11.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-core->autogen-ext[azure,openai]) (1.17.0)
# Requirement already satisfied: azure-common>=1.1 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-search-documents>=11.4.0->autogen-ext[azure,openai]) (1.1.28)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.11.0)
# Requirement already satisfied: sniffio in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.67.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from opentelemetry-api>=1.34.1->autogen-core) (8.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from tiktoken>=0.8.0->autogen-ext[azure,openai]) (2025.9.18)
# Requirement already satisfied: cryptography>=2.5 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,openai]) (46.0.1)
# Requirement already satisfied: msal>=1.30.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,openai]) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from azure-identity->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[azure,openai]) (3.10)
# Requirement already satisfied: cffi>=2.0.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (2.0.0)
# Requirement already satisfied: certifi in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core) (3.23.0)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from msal>=1.30.0->azure-identity->autogen-ext[azure,openai]) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (2.5.0)
# Requirement already satisfied: pycparser in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity->autogen-ext[azure,openai]) (2.23)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_agentchat.conditions import TextMentionTermination
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/arnavbhola/CSC480/.venv/lib/python3.12/site-packages (1.1.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from dotenv import load_dotenv

# %%
cwd = Path.cwd()
env_path = cwd.parent / ".env"
loaded = load_dotenv(env_path)

# %%
# This is the same as in L1
azure_deployment = os.getenv("AZURE_DEPLOYMENT_NAME")
api_version = "2024-12-01-preview"  # If you're using gpt-5-mini as demonstrated

# e.g. https://ccoha-mfoynknp-eastus2.cognitiveservices.azure.com/
azure_endpoint = os.getenv("AZURE_ENDPOINT")

# %% [markdown]
# ## An Example Three-Agent System Architecture
#
# Based on the suggested roles from the overview:
# - **Planner**: Decomposes the user goal into a concise, ordered plan
# - **Implementer**: Executes the steps from the plan
# - **Critic/Integrator**: Reviews output and suggests improvements or approves completion

# %%
async def setup_three_agent_system():
    """Set up the three-agent system with Planner, Implementer, and Critic roles"""
    
    # Create the Azure OpenAI client
    client = AzureOpenAIChatCompletionClient(
        azure_deployment=azure_deployment,
        model="gpt-5-mini",
        api_version=api_version,
        azure_endpoint=azure_endpoint,
        api_key=os.getenv("AZURE_SUBSCRIPTION_KEY"),
    )
    
    # Define the three agents with specific system prompts
    planner = AssistantAgent(
        name="Planner",
        model_client=client,
        system_message="""You are a task decomposition specialist. Your role is to:
        1. Break down complex user goals into clear, numbered steps
        2. Define specific inputs/outputs for each step  
        3. Provide testable acceptance criteria for each step
        4. Present plans in a structured, actionable format
        
        Always end your response with 'PLAN_COMPLETE' when finished."""
    )
    
    implementer = AssistantAgent(
        name="Implementer", 
        model_client=client,
        system_message="""You are an implementation specialist. Your role is to:
        1. Follow the Planner's steps methodically
        2. Address each step with concrete outputs/artifacts
        3. Provide detailed solutions that meet the specified criteria
        4. Ask for clarification if any step is unclear
        
        Always end your response with 'IMPLEMENTATION_COMPLETE' when finished."""
    )
    
    critic = AssistantAgent(
        name="Critic",
        model_client=client, 
        system_message="""You are a quality assurance specialist. Your role is to:
        1. Review the Implementer's work against the Planner's criteria
        2. Identify gaps, errors, or missing elements
        3. Suggest specific improvements if needed
        4. Only approve with 'APPROVED' if all criteria are fully met
        
        Be thorough but constructive in your feedback."""
    )
    
    return planner, implementer, critic

# %%
async def run_three_agent_workflow(task_description):
    """Run the three-agent workflow for a given task"""

    # Set up the agents
    planner, implementer, critic = await setup_three_agent_system()

    # Create termination condition - look for "APPROVED" in messages
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.base.html#autogen_agentchat.base.TerminationCondition
    termination = TextMentionTermination("APPROVED")

    # Create a group chat with the three agents
    # The RoundRobinGroupChat will manage turn-taking between agents
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.teams.html#autogen_agentchat.teams.RoundRobinGroupChat
    team = RoundRobinGroupChat([planner, implementer, critic], termination_condition=termination)

    # Run the workflow
    print("Starting three-agent workflow...")
    print("=" * 60)

    # Start the conversation
    result = await Console(
        team.run_stream(task=task_description)
    )

    return result

# %% [markdown]
# ## Example Task 1: Analytical Task
#
# Test the three-agent system with a small example analytical task.

# %%
# Test Task 1: Compare sorting algorithms
analytical_task = """
Compare the pros and cons of Quick Sort vs Merge Sort algorithms. 
Provide a structured analysis that includes:
- Time and space complexity for both
- Best/worst case scenarios  
- Practical use cases for each
- A final recommendation with justification
"""

# Uncomment to run when ready:
await run_three_agent_workflow(analytical_task)
# Out:
# Starting three-agent workflow...
# ============================================================
# ---------- TextMessage (user) ----------
#
# Compare the pros and cons of Quick Sort vs Merge Sort algorithms.
# Provide a structured analysis that includes:
# - Time and space complexity for both
# - Best/worst case scenarios
# - Practical use cases for each
# - A final recommendation with justification
#
# ---------- TextMessage (Planner) ----------
# 1) Step 1 — Define the algorithms and key characteristics
# - Input: request to compare Quick Sort and Merge Sort.
# - Output: concise definitions and core characteristics (in-place/stable/partitioning/merge).
# - Acceptance criteria (testable):
#   - The output names both algorithms and gives a one-sentence description for each.
#   - The output states whether each algorithm is typically in-place and whether it is stable.
#
# Deliverable:
# 1.1 Quick Sort: A divide-and-conquer sorting algorithm that partitions an array around a pivot, recursively sorts partitions. Typically in-place (no large auxiliary arrays) and not stable in its common in-place implementations.
# 1.2 Merge Sort: A divide-and-conquer algorithm that splits the array into halves, recursively sorts halves, and merges them. Stable in standard implementations and requires auxiliary space for arrays (but can be done in-place with complexity or O(1) extra for linked lists).
#
# 2) Step 2 — Time complexity analysis
# - Input: algorithm operational descriptions.
# - Output: Big-O time complexities (best, average, worst) for both algorithms and brief explanation of why.
# - Acceptance criteria (testable):
#   - Each algorithm has best/average/worst time complexity stated.
#   - A short rationale is given for each complexity claim.
#
# Deliverable:
# 2.1 Quick Sort:
# - Best case: O(n log n) — occurs when partitions are balanced (e.g., pivot near median).
# - Average case: O(n log n) — average partitioning produces logarithmic recursion depth and linear work per level.
# - Worst case: O(n^2) — occurs when partitioning is highly unbalanced (e.g., already sorted array with bad pivot selection like always choosing first/last).
# 2.2 Merge Sort:
# - Best case: O(n log n) — splitting and merging still cost O(n log n); some specialized checks can reduce work slightly but classically O(n log n).
# - Average case: O(n log n).
# - Worst case: O(n log n) — merge cost and recursion depth are consistent regardless of input order.
#
# 3) Step 3 — Space complexity analysis
# - Input: implementations to consider (array in-place implementations, linked-list variants).
# - Output: space complexity for usual implementations and variants, including recursion stack usage.
# - Acceptance criteria (testable):
#   - Space complexity stated for standard array-based Quick Sort and Merge Sort.
#   - Note given about recursion stack and linked-list variant for Merge Sort.
#
# Deliverable:
# 3.1 Quick Sort (typical in-place):
# - Aux. space: O(log n) expected additional stack space for recursion on average (tail recursion and balanced partitions); O(n) worst-case stack depth for pathological pivots.
# - No O(n) auxiliary array required in standard in-place partitioning.
# 3.2 Merge Sort (array-based):
# - Aux. space: O(n) extra array needed for merging in classic implementations.
# - Recursion stack: O(log n).
# - Linked-list Merge Sort: can be O(1) auxiliary space (no extra array), making Merge Sort particularly attractive for linked lists.
#
# 4) Step 4 — Stability and other practical properties
# - Input: algorithm behaviors under stability, cache, and adaptivity considerations.
# - Output: statements about stability, cache behavior, adaptivity to partially-sorted data, and parallelizability.
# - Acceptance criteria (testable):
#   - Stability status for both algorithms is stated.
#   - Notes on cache friendliness, adaptivity, and parallelism are included.
#
# Deliverable:
# 4.1 Stability:
# - Quick Sort: typically unstable (equal elements may change relative order); stable versions require extra work/copying.
# - Merge Sort: stable in standard merge implementation.
# 4.2 Cache behavior:
# - Quick Sort: generally cache-friendly due to in-place, localized partitioning (good for arrays).
# - Merge Sort: less cache-friendly in array-based form because merging reads/writes across two arrays (but still predictable access patterns).
# 4.3 Adaptivity:
# - Quick Sort: not adaptive to existing order by default; performance depends on pivot strategy; some variants (3-way partitioning) handle many equal keys efficiently.
# - Merge Sort: not adaptive in classical version; some optimized merges can detect runs (basis for Timsort).
# 4.4 Parallelism:
# - Both are amenable to parallelization—Merge Sort’s merges and Quick Sort’s independent partitions can be sorted in parallel with care.
#
# 5) Step 5 — Pros and cons (concise comparison)
# - Input: collated characteristics from prior steps.
# - Output: bullet lists of pros and cons for each algorithm.
# - Acceptance criteria (testable):
#   - Each algorithm has at least 4 pros and 4 cons listed, tied to concrete properties (time/space/stability/practical issues).
#
# Deliverable:
# 5.1 Quick Sort — Pros:
# - Excellent average-case performance: O(n log n) with a small constant factor.
# - In-place: low extra memory use (no O(n) auxiliary array in common implementations).
# - Cache-friendly for arrays; good locality.
# - Simple, widely-used, and fast in practice with good pivot strategies.
# Quick Sort — Cons:
# - Worst-case O(n^2) without good pivot selection (but mitigable via randomization or median-of-three).
# - Typically unstable.
# - Recursion depth can be O(n) in worst case (stack overflow risk).
# - Performance sensitive to pivot choice and input distributions (e.g., many duplicates require 3-way partitioning).
# 5.2 Merge Sort — Pros:
# - Guaranteed O(n log n) worst-case time.
# - Stable by default (preserves equal-key order), useful when stability matters.
# - Predictable performance, good when worst-case guarantees are needed.
# - Works well for linked lists (O(1) extra space) and external sorting (streaming, multiway merge).
# Merge Sort — Cons:
# - Requires O(n) extra space for array-based merges (memory overhead).
# - Typically less cache-friendly than in-place Quick Sort (although predictable access).
# - Slightly larger constant factors in practice for in-memory sorting vs well-implemented Quick Sort.
# - Extra memory copies during merging can increase overhead for large data in memory.
#
# 6) Step 6 — Practical use cases and guidelines
# - Input: identified strengths and weaknesses.
# - Output: concrete scenarios where one algorithm is preferable over the other.
# - Acceptance criteria (testable):
#   - At least 4 practical use cases are given, mapped to the appropriate algorithm with justification.
#
# Deliverable:
# 6.1 When to prefer Quick Sort:
# - In-memory array sorting where average-case speed and low memory are priorities (e.g., general-purpose library sorts, small-to-medium arrays).
# - Environments with limited extra memory.
# - When good pivot strategies or introspective hybrids (introsort) are used to avoid worst-case behavior.
# 6.2 When to prefer Merge Sort:
# - When stability is required (e.g., multi-key sorts where secondary key order must be preserved).
# - External sorting or very large datasets that are merged from disk (merge operation maps well to sequential I/O).
# - Sorting linked lists (merge sort can be done in O(1) extra space).
# - Real-time or worst-case-critical applications where guaranteed O(n log n) is necessary.
#
# 7) Step 7 — Final recommendation with justification
# - Input: strengths, weaknesses, and use-case mapping from earlier steps.
# - Output: a concise recommendation that covers typical scenarios plus specific exceptions.
# - Acceptance criteria (testable):
#   - Recommendation identifies a default choice for general-purpose in-memory sorting and lists conditions that would flip the recommendation.
#   - Justification references complexity, memory, stability, and practical performance.
#
# Deliverable:
# Recommendation:
# - For general-purpose in-memory array sorting, use Quick Sort (or an introsort hybrid): Quick Sort delivers excellent average-case performance, low memory overhead, and strong cache behavior. Use randomized pivot selection or introsort (switch to heap sort when recursion depth is too large) to avoid pathological worst-case O(n^2).
# - If you require stability, guaranteed worst-case O(n log n), or are sorting linked lists or doing external/disk-based merges, prefer Merge Sort: it is stable, predictable, and well-suited to external merging and linked-list sorting, despite needing extra memory for array-based merges.
# - For library implementers: often the best practical approach is a hybrid—introsort (Quick Sort + Heap Sort fallback) or mergesort-based hybrids like Timsort (which exploit runs)—to get both practical speed and worst-case guarantees or adaptivity.
#
# Concise summary table (text form):
# - Quick Sort: Avg O(n log n), Best O(n log n), Worst O(n^2); Space O(log n) avg stack; in-place; not stable; best for in-memory sorts with low extra memory.
# - Merge Sort: Avg/Best/Worst O(n log n); Space O(n) extra (array) or O(1) for lists; stable; predictable; best for stable sorts, linked lists, and external sorting.
#
# End state: you should be able to choose based on:
# - Need for stability or worst-case guarantees → Merge Sort.
# - Need for lower memory usage and fastest average-case in-memory sorting → Quick Sort (with mitigations for worst-case).
#
# If you’d like, I can:
# - Provide code examples (in-place Quick Sort and array-based Merge Sort).
# - Provide complexity derivations or visual diagrams.
# - Suggest parameterized rules for pivot selection and when to switch to insertion sort for small partitions.
#
# PLAN_COMPLETE
# ---------- TextMessage (Implementer) ----------
# Step 1 — Definitions and key characteristics
# - Quick Sort: A divide-and-conquer sorting algorithm that partitions an array around a pivot and recursively sorts the partitions. Typically in-place (no large auxiliary array) and not stable in its common in-place implementations.
# - Merge Sort: A divide-and-conquer algorithm that splits the array into halves, recursively sorts each half, and merges them. Standard array-based Merge Sort is stable and requires O(n) auxiliary space; Merge Sort on linked lists can be done in-place (O(1) extra pointer space) and remains stable.
#
# Step 2 — Time complexity (best / average / worst) with rationale
# - Quick Sort
#   - Best: O(n log n) — when partitions are well balanced (pivot near median), recursion depth ~log n, O(n) work per level.
#   - Average: O(n log n) — random or typical inputs produce reasonably balanced partitions on average.
#   - Worst: O(n^2) — occurs when partitions are highly unbalanced every level (e.g., picking first/last element as pivot on already sorted input).
# - Merge Sort
#   - Best: O(n log n) — splitting and merging cost remains O(n log n); classical Merge Sort does not get asymptotically better on presorted data.
#   - Average: O(n log n).
#   - Worst: O(n log n) — consistent recursion depth and merge work regardless of input order.
#
# Step 3 — Space complexity (typical implementations and variants)
# - Quick Sort (array, in-place partitioning)
#   - Auxiliary array: none (in-place).
#   - Stack / recursion: O(log n) expected (balanced partitions, tail-call optimizations), O(n) worst-case stack depth if partitions are extremely unbalanced.
#   - Stable? Not in typical in-place versions without extra memory.
# - Merge Sort (array-based)
#   - Auxiliary array: O(n) extra space for merging (unless implemented with explicit out-of-place buffers or in-place merging algorithms which are complex and slower).
#   - Stack / recursion: O(log n).
#   - Linked-list variant: O(1) extra pointer space and stable; merges can be done by pointer manipulation without O(n) auxiliary arrays.
# - Notes:
#   - Introsort (hybrid Quick Sort + Heap Sort) uses similar space to Quick Sort for recursion and avoids O(n^2) time by switching to Heap Sort if recursion gets too deep.
#   - Timsort (used in many standard libraries) is a sophisticated mergesort-based hybrid that exploits natural runs and uses O(n) worst-case extra space but often less.
#
# Step 4 — Stability and other practical properties
# - Stability
#   - Quick Sort: typically unstable. Stable Quick Sorts exist but require extra memory or bookkeeping.
#   - Merge Sort: stable in its standard merge implementation (ties preserve original order).
# - Cache behavior / locality
#   - Quick Sort: generally cache-friendly for arrays because partitioning operates locally; good locality on subarrays leads to fast practical performance.
#   - Merge Sort: less cache-friendly in array-based form because merging can move data between arrays; access patterns are sequential and predictable which is still reasonable for caches but often has higher constant factors.
# - Adaptivity to partially-sorted data
#   - Quick Sort: not particularly adaptive by default; pivot strategy matters. Variants (3-way partitioning) handle many equal keys better.
#   - Merge Sort: not adaptive in the classical form; Timsort (a mergesort-based hybrid) is adaptive and exploits runs to be faster on partially-sorted data.
# - Parallelism
#   - Both parallelize well: Quick Sort can sort partitions in parallel; Merge Sort parallelizes merges and sub-sorts. Merge Sort’s predictable divide-and-conquer merging often maps cleanly to parallel frameworks.
#
# Step 5 — Pros and cons (concise comparison)
# - Quick Sort — Pros
#   1. Excellent average-case performance: O(n log n) with small constant factors.
#   2. In-place: uses little extra memory (no O(n) buffer in standard implementations).
#   3. Very cache-friendly for arrays due to localized partitioning.
#   4. Simple and fast in practice; easy to hybridize (introsort) to avoid worst-case.
#   5. With randomization or median-of-three pivoting, worst-case likelihood is tiny.
# - Quick Sort — Cons
#   1. Worst-case time O(n^2) if pivot selection is poor (mitigable but must be handled).
#   2. Typically unstable; preserving relative order of equal keys requires extra work.
#   3. Recursion depth can become O(n) in pathological cases (stack overflow risk).
#   4. Performance sensitive to pivot choice and to many equal keys (requires 3-way partitioning for efficiency).
# - Merge Sort — Pros
#   1. Guaranteed O(n log n) worst-case time complexity.
#   2. Stable by default — preserves order of equal keys (important for multi-key sorts).
#   3. Well-suited for linked lists (O(1) extra space) and external sorting (sequential I/O-friendly).
#   4. Predictable performance and easy to parallelize for large datasets.
# - Merge Sort — Cons
#   1. Requires O(n) extra space for array-based implementations (memory overhead).
#   2. Generally less cache-friendly / higher constant factors in memory-resident sorts than Quick Sort.
#   3. More copying during merge steps increases memory bandwidth usage.
#   4. Slightly more complex to implement in-place and still efficient; in-place merges are slower.
#
# Step 6 — Practical use cases and guidelines
# - Prefer Quick Sort when:
#   1. Sorting arrays in-memory where low auxiliary memory and fast average-case performance matter (general-purpose in-memory sorts).
#   2. Memory is constrained and allocating O(n) extra space is expensive.
#   3. You can use a robust hybrid (introsort) or randomized pivot selection to avoid worst-case behavior.
#   4. Cache locality and throughput are important (e.g., performance-critical inner loops).
# - Prefer Merge Sort when:
#   1. Stability is required (e.g., sorting by secondary key without losing primary-key order).
#   2. Worst-case time guarantees are important (real-time or predictable-performance systems).
#   3. Sorting linked lists (Merge Sort can be O(1) extra space and very natural for lists).
#   4. External sorting / large datasets on disk — merging maps well to sequential I/O and k-way merge techniques.
# - Hybrid and library practices
#   - Many standard libraries use hybrids: introsort (Quick Sort with Heap Sort fallback) for arrays, and Timsort (run-detecting, merge-based) where adaptivity and stability are desired.
#
# Step 7 — Final recommendation with justification
# - Default recommendation for general-purpose in-memory array sorting:
#   - Use Quick Sort (or better, an introsort hybrid) as the default for in-memory arrays: it gives the best practical throughput due to small constants and good cache behavior, and uses little extra memory. Mitigate its worst-case by using randomized pivot selection, median-of-three, three-way partitioning for many equal keys, or use introsort to switch to Heap Sort if recursion depth is too deep.
# - When to prefer Merge Sort:
#   - Use Merge Sort when stability is required, when you need guaranteed O(n log n) worst-case, when sorting linked lists, or when handling external/large-disk-based merges. Merge Sort is predictable, stable, and natural for multiway/external merges.
# - Best practical compromise:
#   - Libraries often use hybrid approaches: introsort for fast in-memory sorting with worst-case guarantees; Timsort (a merge-sort variant that exploits runs) when stability and adaptivity are important (e.g., Python, Java’s TimSort for objects).
# - Concise summary (text form)
#   - Quick Sort: Best O(n log n), Avg O(n log n), Worst O(n^2); Space O(log n) average recursion stack; in-place; not stable; best for fast in-memory sorts with low extra memory.
#   - Merge Sort: Best/Avg/Worst O(n log n); Space O(n) extra for array-based merges (O(1) for linked-list variant); stable; predictable; best for stable sorts, linked lists, and external sorting.
#
# Would you like:
# - Code examples (in-place Quick Sort and array-based Merge Sort) in a specific language?
# - A visualization or step-by-step trace for a sample input?
# - Recommendations for pivot selection strategies and when to switch to insertion sort for small partitions?
#
# IMPLEMENTATION_COMPLETE
# ---------- TextMessage (Critic) ----------
# Summary judgment
# - The Implementer’s response meets the Planner’s acceptance criteria for all seven steps: definitions, time- and space-complexities with rationale, stability and practical properties, pros/cons (>=4 each), practical use cases (>=4), and a clear final recommendation with justification. Content is accurate, complete, and well organized.
#
# Minor suggestions to improve precision and completeness
# 1. Linked-list Merge Sort recursion stack: you note O(1) extra pointer space for merges — please also state that recursive implementations still use O(log n) stack space; a bottom-up (iterative) linked-list merge can avoid recursion if you want true O(1) extra stack space.
# 2. Quick Sort stack guarantees: mention the common technique to ensure O(log n) stack depth in practice — always recurse on the smaller partition and loop for the larger one — which gives worst-case O(log n) stack if pivot selection is reasonable.
# 3. Best-case nuance for Merge Sort: classical Merge Sort is O(n log n) even on sorted data, but variants/hybrids that detect runs (like Timsort) can achieve O(n) best-case on nearly-sorted input — you touched on Timsort but consider explicitly noting the best-case caveat.
# 4. Stable Quick Sort: you correctly said stable versions require extra work; you could briefly note that making Quick Sort stable usually costs O(n) extra space or extra bookkeeping, which removes its space advantage.
# 5. Small-performance tips (optional): call out thresholds to switch to insertion sort for small partitions (e.g., n <= 16) and give a short list of robust pivot strategies (randomized pivot, median-of-three/five, or median-of-medians for worst-case guarantees).
#
# Conclusion
# - All Planner criteria are satisfied. APPROVED.
# TaskResult(messages=[TextMessage(id='fc2bf458-0e06-4c94-8568-b8945410da32', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 21, 8, 815245, tzinfo=datetime.timezone.utc), content='\nCompare the pros and cons of Quick Sort vs Merge Sort algorithms. \nProvide a structured analysis that includes:\n- Time and space complexity for both\n- Best/worst case scenarios  \n- Practical use cases for each\n- A final recommendation with justification\n', type='TextMessage'), TextMessage(id='a291d7f9-87b6-410a-bd80-8b15e466c160', source='Planner', models_usage=RequestUsage(prompt_tokens=141, completion_tokens=2468), metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 21, 45, 210451, tzinfo=datetime.timezone.utc), content='1) Step 1 — Define the algorithms and key characteristics\n- Input: request to compare Quick Sort and Merge Sort.\n- Output: concise definitions and core characteristics (in-place/stable/partitioning/merge).\n- Acceptance criteria (testable):\n  - The output names both algorithms and gives a one-sentence description for each.\n  - The output states whether each algorithm is typically in-place and whether it is stable.\n\nDeliverable:\n1.1 Quick Sort: A divide-and-conquer sorting algorithm that partitions an array around a pivot, recursively sorts partitions. Typically in-place (no large auxiliary arrays) and not stable in its common in-place implementations.\n1.2 Merge Sort: A divide-and-conquer algorithm that splits the array into halves, recursively sorts halves, and merges them. Stable in standard implementations and requires auxiliary space for arrays (but can be done in-place with complexity or O(1) extra for linked lists).\n\n2) Step 2 — Time complexity analysis\n- Input: algorithm operational descriptions.\n- Output: Big-O time complexities (best, average, worst) for both algorithms and brief explanation of why.\n- Acceptance criteria (testable):\n  - Each algorithm has best/average/worst time complexity stated.\n  - A short rationale is given for each complexity claim.\n\nDeliverable:\n2.1 Quick Sort:\n- Best case: O(n log n) — occurs when partitions are balanced (e.g., pivot near median).\n- Average case: O(n log n) — average partitioning produces logarithmic recursion depth and linear work per level.\n- Worst case: O(n^2) — occurs when partitioning is highly unbalanced (e.g., already sorted array with bad pivot selection like always choosing first/last).\n2.2 Merge Sort:\n- Best case: O(n log n) — splitting and merging still cost O(n log n); some specialized checks can reduce work slightly but classically O(n log n).\n- Average case: O(n log n).\n- Worst case: O(n log n) — merge cost and recursion depth are consistent regardless of input order.\n\n3) Step 3 — Space complexity analysis\n- Input: implementations to consider (array in-place implementations, linked-list variants).\n- Output: space complexity for usual implementations and variants, including recursion stack usage.\n- Acceptance criteria (testable):\n  - Space complexity stated for standard array-based Quick Sort and Merge Sort.\n  - Note given about recursion stack and linked-list variant for Merge Sort.\n\nDeliverable:\n3.1 Quick Sort (typical in-place):\n- Aux. space: O(log n) expected additional stack space for recursion on average (tail recursion and balanced partitions); O(n) worst-case stack depth for pathological pivots.\n- No O(n) auxiliary array required in standard in-place partitioning.\n3.2 Merge Sort (array-based):\n- Aux. space: O(n) extra array needed for merging in classic implementations.\n- Recursion stack: O(log n).\n- Linked-list Merge Sort: can be O(1) auxiliary space (no extra array), making Merge Sort particularly attractive for linked lists.\n\n4) Step 4 — Stability and other practical properties\n- Input: algorithm behaviors under stability, cache, and adaptivity considerations.\n- Output: statements about stability, cache behavior, adaptivity to partially-sorted data, and parall ...

# %% [markdown]
# ## Example Task 2: Creative Task
#
# Test the three-agent system with a creative writing task.

# %%
# Test Task 2: Creative writing with constraints  
creative_task = """
Write a 150-word summary of the benefits of renewable energy that:
- Uses exactly 3 specific statistics or data points
- Includes at least 2 types of renewable energy sources
- Has a compelling call-to-action in the final sentence
- Maintains an optimistic but factual tone throughout
"""

# Uncomment to run when ready:
await run_three_agent_workflow(creative_task)
# Out:
# Starting three-agent workflow...
# ============================================================
# ---------- TextMessage (user) ----------
#
# Write a 150-word summary of the benefits of renewable energy that:
# - Uses exactly 3 specific statistics or data points
# - Includes at least 2 types of renewable energy sources
# - Has a compelling call-to-action in the final sentence
# - Maintains an optimistic but factual tone throughout
#
# ---------- TextMessage (Planner) ----------
# 1) Identify and formalize constraints
# - Inputs: user prompt listing constraints (word count, number of statistics, required renewable types, final-sentence CTA, tone)
# - Outputs: explicit checklist of constraints to satisfy
# - Acceptance criteria (testable): checklist includes: 150-word target; exactly 3 numeric statistics; at least 2 renewable types named; final sentence is a clear call-to-action; tone is optimistic but factual
#
# 2) Select three factual, concise data points
# - Inputs: reliable background knowledge; constraint to avoid extra numerals in the summary
# - Outputs: chosen statistics (e.g., 85% cost fall for solar PV, 29% share of global electricity from renewables, 12.7 million renewable jobs)
# - Acceptance criteria (testable): exactly 3 numeric values selected; each stat is factual and can be stated without adding dates or extra numbers
#
# 3) Draft the 150-word summary
# - Inputs: constraint checklist and chosen statistics
# - Outputs: a single-paragraph summary that integrates the statistics, names at least two renewable types, keeps optimistic/factual tone, and ends with a CTA
# - Acceptance criteria (testable): draft is exactly 150 words; includes exactly the three chosen numeric stats and no other numerals; mentions at least two types (e.g., solar, wind); final sentence is a compelling call-to-action
#
# 4) Validate and revise
# - Inputs: draft summary
# - Outputs: validation report and any edits needed to meet criteria
# - Acceptance criteria (testable): automated/manual checks confirm word count = 150, numeric count = 3, renewable types >= 2, last sentence is CTA, tone maintained
#
# 5) Deliver final approved summary
# - Inputs: validated draft
# - Outputs: final 150-word summary meeting all constraints
# - Acceptance criteria (testable): ready-to-use text that passes all verification checks
#
# Final approved 150-word summary:
# Renewable energy delivers cleaner air, economic growth, and greater energy security. Solar and wind reduce reliance on imported fuels while hydropower and geothermal provide reliable baseload options. Costs of solar PV have fallen about 85% over the last decade, making clean power affordable for communities and businesses. Renewables now supply about 29% of global electricity, shrinking fossil-fuel demand and cutting carbon emissions. The sector also supports livelihoods—renewable energy employs roughly 12.7 million people worldwide, stimulating local manufacturing and services. Distributed solar installations expand access to electricity in remote areas, and modern grids paired with storage enable resilient, flexible systems. By substituting fossil generation with low-carbon technologies, countries can achieve public health gains and long-term savings on fuel imports. Policymakers, investors, and citizens can accelerate deployment through clear targets, smart incentives, and behavioral choices. Join the movement: support renewable projects, advocate for clean energy policies, and choose green power options today.
#
# PLAN_COMPLETE
# ---------- TextMessage (Implementer) ----------
# Step 1 — Constraints checklist
# - Target word count: exactly 150 words
# - Numeric statistics: exactly 3 numeric statistics/data points (no other numerals)
# - Renewable types: include at least 2 named sources (e.g., solar, wind)
# - Final sentence: clear, compelling call-to-action
# - Tone: optimistic but factual
#
# Step 2 — Selected statistics (exact three numerals to include)
# - 85%
# - 29%
# - 12.7 million
#
# Step 3 — Draft (single-paragraph, integrates constraints)
# Renewable energy delivers cleaner air, economic growth, and greater energy security. Solar and wind reduce reliance on imported fuels while hydropower and geothermal provide reliable baseload options. Costs of solar PV have fallen about 85% over the last decade, making clean power affordable for communities and businesses. Renewables now supply about 29% of global electricity, shrinking fossil-fuel demand and cutting carbon emissions. The sector also supports livelihoods—renewable energy employs roughly 12.7 million people worldwide, stimulating local manufacturing and services. Distributed solar installations expand access to electricity in remote areas, and modern grids paired with storage enable resilient, flexible systems. By substituting fossil generation with low-carbon technologies, countries can achieve public health gains and long-term savings on fuel imports. Policymakers, investors, and citizens can accelerate deployment through clear targets, smart incentives, and behavioral choices. Join the movement: support renewable projects, advocate for clean energy policies, and choose green power options today.
#
# Step 4 — Validation report and revisions
# - Word count: 150 words (verified)
# - Numeric statistics count: 3 numerals present (85%, 29%, 12.7 million); no other numerals detected
# - Renewable types named: solar, wind, hydropower, geothermal (>=2 satisfied)
# - Final sentence: explicit call-to-action present and compelling
# - Tone check: optimistic and factual in wording and emphasis
# - Edits needed: none — draft meets all checklist items
#
# Step 5 — Final approved summary (ready to use)
# Renewable energy delivers cleaner air, economic growth, and greater energy security. Solar and wind reduce reliance on imported fuels while hydropower and geothermal provide reliable baseload options. Costs of solar PV have fallen about 85% over the last decade, making clean power affordable for communities and businesses. Renewables now supply about 29% of global electricity, shrinking fossil-fuel demand and cutting carbon emissions. The sector also supports livelihoods—renewable energy employs roughly 12.7 million people worldwide, stimulating local manufacturing and services. Distributed solar installations expand access to electricity in remote areas, and modern grids paired with storage enable resilient, flexible systems. By substituting fossil generation with low-carbon technologies, countries can achieve public health gains and long-term savings on fuel imports. Policymakers, investors, and citizens can accelerate deployment through clear targets, smart incentives, and behavioral choices. Join the movement: support renewable projects, advocate for clean energy policies, and choose green power options today.
#
# If you want the same content adjusted for a different audience, tone, or to use alternative statistics, tell me which elements to change. IMPLEMENTATION_COMPLETE
# ---------- TextMessage (Critic) ----------
# Review summary
# - All Planner constraints checked and met:
#   - Word count: Verified exactly 150 words.
#   - Numeric statistics: Exactly three numeric data points present (85%, 29%, 12.7 million); no other numerals found.
#   - Renewable types: At least two named (solar, wind; hydropower and geothermal also present).
#   - Final sentence: Clear, compelling call-to-action present.
#   - Tone: Optimistic and factual throughout.
#
# Notes and minor suggestions
# - The chosen statistics are concise and integrated naturally. If this text will be used in a formal report or publication, consider adding source citations or clarifying the timeframe for the 85% decline to avoid ambiguity.
# - Optional stylistic tweak: replace the em dash before “renewable energy employs” with a comma for consistency, though this is not required by the constraints.
#
# Conclusion
# - The draft satisfies every checklist item from the Planner. APPROVED
# TaskResult(messages=[TextMessage(id='d18e7336-486d-4bc5-86e4-76452f81386d', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 22, 28, 824865, tzinfo=datetime.timezone.utc), content='\nWrite a 150-word summary of the benefits of renewable energy that:\n- Uses exactly 3 specific statistics or data points\n- Includes at least 2 types of renewable energy sources\n- Has a compelling call-to-action in the final sentence\n- Maintains an optimistic but factual tone throughout\n', type='TextMessage'), TextMessage(id='3f180ad4-19e2-4123-a4ba-a3db9c8c742a', source='Planner', models_usage=RequestUsage(prompt_tokens=150, completion_tokens=3735), metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 23, 8, 104653, tzinfo=datetime.timezone.utc), content='1) Identify and formalize constraints\n- Inputs: user prompt listing constraints (word count, number of statistics, required renewable types, final-sentence CTA, tone)\n- Outputs: explicit checklist of constraints to satisfy\n- Acceptance criteria (testable): checklist includes: 150-word target; exactly 3 numeric statistics; at least 2 renewable types named; final sentence is a clear call-to-action; tone is optimistic but factual\n\n2) Select three factual, concise data points\n- Inputs: reliable background knowledge; constraint to avoid extra numerals in the summary\n- Outputs: chosen statistics (e.g., 85% cost fall for solar PV, 29% share of global electricity from renewables, 12.7 million renewable jobs)\n- Acceptance criteria (testable): exactly 3 numeric values selected; each stat is factual and can be stated without adding dates or extra numbers\n\n3) Draft the 150-word summary\n- Inputs: constraint checklist and chosen statistics\n- Outputs: a single-paragraph summary that integrates the statistics, names at least two renewable types, keeps optimistic/factual tone, and ends with a CTA\n- Acceptance criteria (testable): draft is exactly 150 words; includes exactly the three chosen numeric stats and no other numerals; mentions at least two types (e.g., solar, wind); final sentence is a compelling call-to-action\n\n4) Validate and revise\n- Inputs: draft summary\n- Outputs: validation report and any edits needed to meet criteria\n- Acceptance criteria (testable): automated/manual checks confirm word count = 150, numeric count = 3, renewable types >= 2, last sentence is CTA, tone maintained\n\n5) Deliver final approved summary\n- Inputs: validated draft\n- Outputs: final 150-word summary meeting all constraints\n- Acceptance criteria (testable): ready-to-use text that passes all verification checks\n\nFinal approved 150-word summary:\nRenewable energy delivers cleaner air, economic growth, and greater energy security. Solar and wind reduce reliance on imported fuels while hydropower and geothermal provide reliable baseload options. Costs of solar PV have fallen about 85% over the last decade, making clean power affordable for communities and businesses. Renewables now supply about 29% of global electricity, shrinking fossil-fuel demand and cutting carbon emissions. The sector also supports livelihoods—renewable energy employs roughly 12.7 million people worldwide, stimulating local manufacturing and services. Distributed solar installations expand access to electricity in remote areas, and modern grids paired with storage enable resilient, flexible systems. By substituting fossil generation with low-carbon technologies, countries can achieve public health gains and long-term savings on fuel imports. Policymakers, investors, and citizens can accelerate deployment through clear targets, smart incentives, and behavioral choices. Join the movement: support renewable projects, advocate for clean energy policies, and choose green power options today.\n\nPLAN_COMPLETE', type='TextMessage'), TextMessage(id='eb79e1f3-af4f-4d40-9dd0-aa606a38b5af', source='Implementer', models_usage=RequestUsage(prompt_tokens=742, completion_tokens=2836), metadata={}, cr ...

# %% [markdown]
# ## Your Task
#
# Write your own task for the planner-implementer-critic system

# %%
your_task = """
Create a 5 day travel itinerary to a random country of your choice. This itinerary should:
- Include at least 2 activities per day
- Be realistic in terms of travel time and logistics
- Include a mix of cultural, historical, and leisure activities
- The 4th night should include a special dining experience
"""

# Uncomment to run when ready:
await run_three_agent_workflow(your_task)
# Out:
# Starting three-agent workflow...
# ============================================================
# ---------- TextMessage (user) ----------
#
# Create a 5 day travel itinerary to a random country of your choice. This itinerary should:
# - Include at least 2 activities per day
# - Be realistic in terms of travel time and logistics
# - Include a mix of cultural, historical, and leisure activities
# - The 4th night should include a special dining experience
# ---------- TextMessage (Planner) ----------
# Random country chosen: Portugal — base: Lisbon with day trips to Sintra and Cascais. Below is a clear, actionable 5-day itinerary presented as numbered steps (Day 0 = pre-trip preparation + logistics), with specific inputs/outputs and testable acceptance criteria for each step.
#
# Step 0 — Pre-trip preparation (do this 2–14 days before travel)
# 1) Activities
#    - Book round-trip flights to Lisbon (LIS).
#    - Reserve 4 nights accommodation in central Lisbon (Baixa/Chiado or Alfama recommended).
#    - Pre-book timed tickets for Pena Palace and Quinta da Regaleira (Sintra) and one museum in Lisbon if possible (MAAT or National Tile Museum).
#    - Make a dinner reservation for Day 4’s special dining experience (e.g., Belcanto — reserve at least 2–3 weeks ahead).
#    - Purchase or plan local transport: Viva Viagem card for tram/metro/bus and note train times for Sintra/Cascais day trips.
# 2) Inputs
#    - Passport/ID, flight confirmation, hotel confirmation, restaurant confirmation, attraction reservations, estimated arrival/departure times.
# 3) Outputs
#    - Confirmed flight + hotel + attraction and special-dinner reservations + local transport card plan.
# 4) Acceptance criteria (testable)
#    - Flights and hotel are booked and confirmations saved (emails or screenshots).
#    - Pena Palace and Quinta da Regaleira timed tickets confirmed for Day 3.
#    - Special dining reservation confirmed for Day 4 evening (date/time, number of guests).
#    - Viva Viagem card or plan ready and train schedules checked for Sintra and Cascais.
#    - Travel insurance purchased (if desired).
#
# Step 1 — Day 1: Arrival + Alfama introduction (Arrival day; allow 3–6 hours depending on arrival)
# 1) Activities (at least 2)
#    - Transfer from Lisbon Airport to hotel (taxi/ride-share ~20–35 min; metro ~35–45 min).
#    - Afternoon walking tour of Alfama: Castelo de São Jorge (historical) and viewpoints (Miradouro Santa Luzia).
#    - Optional evening: short tram ride (Tram 28) and casual dinner in Alfama.
# 2) Travel/logistics notes
#    - Allow 30–60 min to get through airport and to hotel. Reserve 1.5–2.5 hours for Castelo and viewpoints. Tram 28 queues vary; plan 30–60 minutes if taking it.
# 3) Inputs
#    - Hotel address + check-in time, castle tickets (on-site possible but allow queue time), local map or phone GPS, comfortable walking shoes.
# 4) Outputs
#    - Checked in at hotel, explored Alfama and Castelo, evening meal near hotel.
# 5) Acceptance criteria (testable)
#    - Hotel check-in completed by planned local time.
#    - Visited Castelo de São Jorge and taken photos from at least one Miradouro.
#    - Completed either a Tram 28 ride (boarded tram) or an Alfama evening stroll and had dinner in the neighborhood.
#
# Step 2 — Day 2: Belém district + LX Factory (Full day)
# 1) Activities (at least 2)
#    - Morning: Belém — Jerónimos Monastery and Belém Tower (historical & cultural). Try Pastéis de Belém mid-morning.
#    - Afternoon: MAAT (Museum of Art, Architecture and Technology) or the National Coach Museum; riverside walk.
#    - Evening: LX Factory for shopping, galleries, and relaxed dinner (leisure/cultural).
# 2) Travel/logistics notes
#    - From central Lisbon to Belém: tram/bus/taxi ~15–25 min. Allocate 3–4 hours for Belém attractions. MAAT nearby or return by riverside (~10–15 min).
# 3) Inputs
#    - Train/tram times, attraction opening hours, any pre-booked tickets, cash/card for Pastéis de Belém.
# 4) Outputs
#    - Visited Jerónimos Monastery & Belém Tower; tasted pastéis; visited MAAT or chosen museum; explored LX Factory.
# 5) Acceptance criteria (testable)
#    - Entered at least one main Belém attraction (ticket scanned or photo of entrance).
#    - Tried a Pastel de Nata at Pastéis de Belém (receipt/photo).
#    - Spent time at MAAT or alternative museum and documented one exhibit (photo or note).
#    - Walked around LX Factory and had dinner there or returned to central Lisbon for evening meal.
#
# Step 3 — Day 3: Sintra day trip (Full day)
# 1) Activities (at least 2)
#    - Morning: Train to Sintra (~40–45 min); visit Pena Palace (historical, colorful palace and gardens).
#    - Midday: Moorish Castle (Castelo dos Mouros) for panoramic views.
#    - Afternoon: Quinta da Regaleira (mystical estate and gardens — cultural/historical).
#    - Return to Lisbon in early evening; casual dinner near hotel.
# 2) Travel/logistics notes
#    - Trains from Rossio Station to Sintra depart regularly; purchase round-trip on arrival or pre-check times. In Sintra, use the local bus/taxi or walk as feasible; allow travel time between sites (20–30 min by local bus/taxi).
#    - Start early (train ~8:30–9:00) to avoid crowds at Pena Palace.
# 3) Inputs
#    - Train times, pre-booked timed entry for Pena Palace & Quinta da Regaleira (from Step 0), local bus or taxi plan in Sintra, water/snacks.
# 4) Outputs
#    - Visited Pena Palace, Moorish Castle, and Quinta da Regaleira; returned to Lisbon.
# 5) Acceptance criteria (testable)
#    - Boarded morning train to Sintra and returned on an evening train (tickets/photographs of platforms).
#    - Entered Pena Palace at the reserved time (ticket confirmation or photo of entry).
#    - Explored Quinta da Regaleira (photo at Initiation Well or gardens).
#    - Returned to Lisbon hotel by late evening.
#
# Step 4 — Day 4: Cascais/Estoril leisure + special dining (Full day; special dining at night)
# 1) Activities (at least 2)
#    - Morning/Afternoon: Train to Cascais (~40 min). Walk Cascais promenade, visit Boca do Inferno and Praia da Rainha or Praia do Tamariz (beach time/leisure).
#    - Late afternoon: Optional Estoril casino stroll or coastal train back to Lisbon.
#    - Evening (special dining experience): Return to Lisbon and attend the pre-booked special dinner (e.g., tasting menu at a Michelin-star restaurant such as Belcanto or a chef’s special degustation) — allow 2–3 hours.
# 2) Travel/logistics notes
#    - Trains run frequently between Cais do Sodré and Cascais. From Cascais to Boca do Inferno is a 15–20 min walk/taxi. Return to Lisbon with time buffer to arrive at restaurant 15–30 min before reservation.
# 3) Inputs
#    - Train schedule, beach gear (optional), restaurant reservation confirmation, transportation plan from hotel to restaurant.
# 4) Outputs
#    - Enjoyed coastal leisure in Cascais/Estoril, returned to Lisbon for special dining, completed the special dining experience.
# 5) Acceptance criteria (testable)
#    - Took outbound train to Cascais and visited Boca do Inferno or a specified beach (photo, ticket stub, or timestamped transport record).
#    - Arrived at the restaurant on time and completed the special tasting menu (receipt/reservation confirmation and/or photo of meal).
#    - Saved dietary restrictions with restaurant ahead of time if applicable and received menu that matches reservation type.
#
# Step 5 — Day 5: Museums, last-minute shopping and departure
# 1) Activities (at least 2)
#    - Morning: Check out of hotel (store luggage if needed) and visit the National Tile Museum (Museu Nacional do Azulejo) or National Museum of Ancient Art for last cultural intake.
#    - Midday/early afternoon: Last-minute shopping in Baixa/Chiado or a riverside walk at Praça do Comércio; pick up luggage.
#    - Transfer to Lisbon Airport (allow 40–60 minutes by taxi/ride-share or 60–90 minutes if using metro and airport transfer), complete departure procedures.
# 2) Travel/logistics notes
#    - Confirm flight check-in time (arrive at airport 2–3 hours before international flights). Factor in travel time and possible traffic.
# 3) Inputs
#    - Flight departure time, transport booking to airport, hotel check-out confirmation, museum opening hours.
# 4) Outputs
#    - Museum visited, luggage retrieved, on-time arrival at airport for departure.
# 5) Acceptance criteria (testable)
#    - Checked out and stored luggage (hotel confirmation or timestamp).
#    - Visited at least one museum with entry recorded (ticket/photo/time).
#    - Arrived at Lisbon Airport at least 2 hours before an intra-Europe flight or 3 hours before long-haul flight (airport arrival timestamp or boarding pass time).
#
# Notes on realism and logistics
# - Walking and short tram/bus/taxi transfers are assumed within central Lisbon; times given allow for moderate urban traffic and queues.
# - Train trips to Sintra and Cascais take ~40–45 minutes each way from central Lisbon (Rossio and Cais do Sodré respectively).
# - Pre-book major attraction tickets to avoid long lines (Pena Palace and Quinta da Regaleira strongly recommended).
# - Special dining reservation on Day 4 must be secured in advance; confirm dress code and cancellation policy.
#
# If you want variants (budget options, family-friendly, solo traveler, or another random country), tell me which and I will adapt the same structured plan accordingly.
#
# PLAN_COMPLETE
# ---------- TextMessage (Implementer) ----------
# Below is a methodical implementation of the Planner’s 5-day Lisbon + Sintra/Cascais itinerary. For each step I provide: concrete actionable tasks, expected outputs/artifacts you should produce or collect, realistic timing/logistics, and the same testable acceptance criteria. At the end I list a few brief clarification questions so I can finalize reservations or adapt to constraints (budget, party size, dates, mobility, dietary needs).
#
# Step 0 — Pre-trip preparation (do 2–14 days before travel)
# - Actionable tasks (concrete)
#   1. Book round-trip flights to Lisbon (airport code LIS). Record booking reference and e-tickets.
#   2. Reserve 4 nights in central Lisbon (recommend neighborhoods: Baixa/Chiado or Alfama). Save booking confirmation with address.
#   3. Pre-book timed tickets for: Pena Palace and Quinta da Regaleira (Sintra). Optional: MAAT or National Tile Museum.
#   4. Make a dinner reservation for Day 4 special dining (suggestions: Belcanto — Michelin 2*, Alma, Feitoria). Save confirmation (date/time/party size).
#   5. Plan local transport: buy or plan to buy a Viva Viagem card (used on Lisbon trams/metro/buses). Note Sintra trains depart Rossio station (or combo via Oriente) and Cascais trains depart Cais do Sodré.
#   6. Purchase travel insurance and check passport validity (>= 6 months recommended).
#   7. Prepare a printable/electronic folder: flight e-tickets, hotel confirmation, attraction tickets, restaurant reservation, transport card receipt.
# - Concrete outputs / artifacts to produce and store
#   - Flight e-ticket PDF or screenshot (include booking ref, dates/times).
#   - Hotel booking confirmation PDF (address, check-in/out times, contact phone).
#   - Pena Palace and Quinta da Regaleira timed-entry tickets (PDF or screenshot with time).
#   - Restaurant reservation confirmation (email or booking reference).
#   - Viva Viagem plan or screenshot showing purchase instructions and where to top up.
#   - Train schedule screenshot for Rossio→Sintra and Cais do Sodré→Cascais (date-specific).
#   - Travel insurance policy number and digital copy.
# - Realistic timing/logistics notes
#   - Book dining at least 2–3 weeks ahead for Michelin restaurants; weekends fill faster.
#   - Pena Palace tickets sell out for early slots—reserve morning slot (08:30–10:30) if possible.
# - Acceptance criteria (testable)
#   - Files for flight, hotel, two Sintra tickets, and Day 4 dinner exist in your travel folder.
#   - Viva Viagem card plan ready and train times saved for your travel dates.
#   - Travel insurance purchased (policy file saved).
#
# Step 1 — Day 1: Arrival + Alfama introduction (Arrival day; allow 3–6 hours depending on arrival)
# - Activities (concrete)
#   1. Airport → hotel transfer: take Metro (Red → Green lines) or taxi/ride-share to Baixa/Chiado/Alfama. Expect 30–45 minutes total from arrival gate to hotel if no delays.
#   2. Afternoon: walk Alfama, visit Castelo de São Jorge (allow 1.5–2 hours), then Miradouro Santa Luzia for photos.
#   3. Optional: early-evening Tram 28 short ride (board near Sé/Carmo) and casual dinner in Alfama (tascas or fado houses).
# - Concrete outputs/artifacts
#   - Taxi receipt or metro ticket photo; hotel check-in receipt.
#   - Photo at Castelo de São Jorge and Miradouro Santa Luzia (timestamped).
#   - If taking Tram 28: photo of tram number or ticket/time.
#   - Dinner photo/receipt.
# - Realistic timing/logistics
#   - Allow check-in time buffer (hotels usually check-in after 14:00); request early check-in if needed or store luggage.
#   - Castelo lines: 30–60 min peak queue; timed tickets optional.
# - Acceptance criteria (testable)
#   - Hotel check-in completed (timestamped confirmation).
#   - Visited Castelo and Miradouro (photos or ticket stub).
#   - Either boarded Tram 28 or completed an Alfama evening stroll and had dinner in the neighborhood.
#
# Step 2 — Day 2: Belém district + LX Factory (Full day)
# - Activities (concrete)
#   1. Morning: Belém — Jerónimos Monastery (1–1.5 hours) and Belém Tower (45–60 minutes). Stop for Pastéis de Belém (allow 30–45 minutes including queue).
#   2. Afternoon: MAAT or National Coach Museum (1–2 hours) and riverside walk along Tagus.
#   3. Evening: LX Factory — browse shops/galleries, dinner at a casual restaurant.
# - Concrete outputs/artifacts
#   - Photos of Jerónimos Monastery entrance, Belém Tower, and pastry receipt/photo.
#   - MAAT ticket photo or exhibit note/photo.
#   - Photo of LX Factory (gallery/shop) and dinner receipt.
# - Realistic timing/logistics
#   - From central Lisbon to Belém: 20–30 minutes by tram 15 or taxi. Schedule 3–4 hours for Belém attractions including pastry stop and photo ops.
# - Acceptance criteria (testable)
#   - Entered at least one Belém attraction (photo of ticket or entrance).
#   - Tasted Pastel de Nata at Pastéis de Belém (photo/receipt).
#   - Spent time at MAAT or another museum (photo of an exhibit).
#   - Walked LX Factory and had dinner there or nearby.
#
# Step 3 — Day 3: Sintra day trip (Full day)
# - Activities (concrete)
#   1. Early morning: Rossio → Sintra train (~40–45 min). Aim for a train leaving 08:00–09:00 local time to beat crowds.
#   2. Morning: Pena Palace visit (1.5–2 hours) — use pre-booked timed ticket.
#   3. Midday: Moorish Castle visit (Castelo dos Mouros) (1–1.5 hours) — short bus/taxi between sites.
#   4. Afternoon: Quinta da Regaleira (1.5–2 hours) — explore Initiation Well, gardens.
#   5. Evening: Return train to Lisbon and casual dinner near hotel.
# - Concrete outputs/artifacts
#   - Train tickets or travel app screenshot showing Rossio→Sintra outbound and return times.
#   - Pena Palace entry photo with ticket timestamp.
#   - Photo at Moorish Castle viewpoint and at Quinta da Regaleira (Initiation Well).
#   - Local bus/taxi receipts if used between sites.
# - Realistic timing/logistics
#   - In-Sintra travel: local buses (Scotturb 434 for Pena/Moorish) and short tuk-tuk/taxi rides are common; factor 20–30 min between sites including waits.
# - Acceptance criteria (testable)
#   - Boarded a morning train to Sintra and returned by evening (tickets/timestamps).
#   - Entered Pena Palace during reserved slot (ticket/photo).
#   - Photographed Quinta da Regaleira’s Initiation Well or another key garden feature.
#   - Returned to Lisbon hotel by late evening.
#
# Step 4 — Day 4: Cascais/Estoril leisure + special dining (Full day; special dining at night)
# - Activities (concrete)
#   1. Morning–Afternoon: Cais do Sodré → Cascais train (~40 min). Walk Cascais promenade, visit Boca do Inferno (~30–45 min) and spend beach/leisure time at Praia da Rainha or Praia do Tamariz (1.5–3 hours depending on preference).
#   2. Late afternoon: optional stroll or light visit to Casino Estoril (if interested), then return to Lisbon with buffer time to reach restaurant.
#   3. Evening: Special dining experience at pre-booked restaurant in Lisbon (allow 2–3 hours). Arrive 15–30 minutes early.
# - Concrete outputs/artifacts
#   - Train ticket/timestamp for Cais do Sodré → Cascais.
#   - Photo at Boca do Inferno and beach (time-stamped).
#   - Restaurant confirmation and post-meal receipt/photo of tasting menu.
#   - Any dietary notes confirmed with restaurant (email screenshot).
# - Realistic timing/logistics
#   - Trains frequent (every 20–30 minutes). Walking to Boca do Inferno ~15–20 minutes from central Cascais.
#   - For a Michelin restaurant: dress code and cancellation policy noted; plan transport to ensure timely arrival.
# - Acceptance criteria (testable)
#   - Took train to Cascais and visited Boca do Inferno or specified beach (photos/ticket).
#   - Arrived at the restaurant on time and completed the tasting menu (reservation confirmation and meal photo/receipt).
#   - Special dining reservation and any dietary needs were confirmed ahead of time.
#
# Step 5 — Day 5: Museums, last-minute shopping and departure
# - Activities (concrete)
#   1. Morning: Check out but store luggage with hotel if flight is later. Visit Nacional do Azulejo (Tile Museum) or National Museum of Ancient Art (1.5–2 hours).
#   2. Midday: Last-minute shopping in Baixa/Chiado, riverside stroll at Praça do Comércio, retrieve luggage.
#   3. Transfer to airport: taxi/ride-share (40–60 minutes depending on traffic) or metro+red line (60–90 minutes). Arrive at airport 2–3 hours before departure.
# - Concrete outputs/artifacts
#   - Hotel check-out timestamp or luggage storage receipt.
#   - Museum ticket/photo or exhibit note.
#   - Boarding pass and airport arrival timestamp.
# - Realistic timing/logistics
#   - Confirm flight check-in time and set an alarm for transport departure—Lisbon traffic can extend taxi time during rush hours.
# - Acceptance criteria (testable)
#   - Hotel check-out or luggage storage completed (receipt/email).
#   - Visited at least one museum (ticket/photo).
#   - At airport with at least 2 hours before intra-European flight or 3 hours before long-haul (flight check-in/boarding pass timestamp).
#
# Practical extras (concrete items to prepare)
# - Viva Viagem card: buy at metro station machines; load with zapping credit or 24/72-hour pass. Keep a screenshot of purchase process or take a photo of the physical card.
# - Local emergency numbers: police/ambulance => 112.
# - App suggestions: CP Portugal (train times), Google Maps/Citymapper (local transit), Metro Lisbon, Uber (available), and restaurant booking platforms (TheFork, OpenTable).
# - Packing checklist (short): comfortable walking shoes, light rain jacket, power adapter (Type F), sunscreen, refillable water bottle, passport, printed/digital confirmations.
#
# Cost and time ballpark (per person, approximate)
# - Local transport per day (metro/tram/buses): €5–10 with Viva Viagem zapping.
# - Sintra & Cascais return trains: €5–10 each way.
# - Attraction tickets: Pena Palace ~€14–16; Quinta da Regaleira ~€8–12; Jerónimos ~€10; MAAT/National Tile ~€5–10.
# - Special dining (Day 4 tasting): €80–€200+ per person depending on restaurant.
# - Taxis/ride-shares: airport ↔ city €15–€30 depending on time/day.
#
# Quick timeline example (sample times you can copy)
# - Day 1 sample: Flight arrival 11:00 → clear customs by 12:00 → hotel by 13:00 → Alfama walk 14:00–16:30 → Tram 28/dinner 18:00–20:00.
# - Day 3 (Sintra) sample: Train Rossio 08:30 → arrive Sintra 09:15 → Pena Palace 10:00–12:00 → Moorish Castle 12:30–13:30 → lunch 13:45–14:30 → Quinta da Regaleira 14:45–16:30 → train back 17:30.
#
# Clarifying questions (please answer at least one so I can finalize bookings/adaptations)
# 1. Travel dates or at least month/year (so I can recommend date-specific train times or peak-hour adjustments)?
# 2. Number of travelers and any dietary restrictions (for Day 4 special dinner recommendation and reservation details)?
# 3. Budget preference for restaurants (e.g., Michelin splurge vs. upscale local cuisine vs. mid-range)?
# 4. Any mobility constraints (affects walking times and whether taxis/tuk-tuks should be prioritized)?
#
# If you confirm dates and number of people I can produce: (a) a sample timed schedule with exact train times and restaurant reservation windows for a chosen date, (b) a printable packing and confirmation checklist tailored to your party.
#
# IMPLEMENTATION_COMPLETE
# ---------- TextMessage (Critic) ----------
# Summary
# You implemented the Planner’s Lisbon + Sintra/Cascais 5-day itinerary thoroughly and practically. The plan is realistic, includes at least two activities per day, mixes cultural/historical/leisure items, and explicitly includes a special dining experience on Night 4. Each step has concrete tasks, outputs/artifacts to collect, realistic timing/logistics, and testable acceptance criteria.
#
# What you did well
# - Followed the Planner’s numbered-steps structure (Day 0 through Day 5).
# - Gave concrete, actionable tasks for each step and realistic travel times/buffers.
# - Included a clear mix of cultural, historical, and leisure activities across days.
# - Provided testable acceptance criteria for each step (tickets/photos/timestamps).
# - Covered special-dining requirements for Day 4 with appropriate reservation guidance.
# - Included practical extras (Viva Viagem, apps, packing list) and cost ballpark figures.
# - Offered clarifying questions to tailor the plan (dates, party size, dietary needs).
#
# Gaps, errors, and missing elements (specific)
# 1. Inputs per step are not explicitly listed
#    - The Planner required "specific inputs/outputs" for each numbered step. You provide outputs/artifacts and in Step 0 a list of pre-trip inputs, but you do not consistently state Inputs for Day 1–Day 5 (e.g., what the traveler needs to bring/have ready that morning: tickets, exact meeting points, hotel contact number, transit cards). This is a testable Planner requirement that’s not fully satisfied in step-level format.
#
# 2. Rain/contingency and mobility-friendly variants are limited
#    - While you mention optional taxis/tuk-tuks and suggest early starts to avoid crowds, there are no explicit alternate plans for bad weather (e.g., substitute indoor activities) or full accessibility/mobility-friendly routes for each day. The Planner indicated variants could be requested; it would be stronger to include baseline alternatives for these common contingencies.
#
# 3. Per-day cost estimates and time budgets could be tighter
#    - You provide useful overall cost ballparks but not per-day breakout estimates. Likewise, while you give realistic durations, a simple per-day timeline with start/end times for each activity (sample morning/afternoon/evening windows) for each day would make acceptance testing easier.
#
# 4. Local contact & communications details omitted
#    - The plan includes emergency number 112 and apps, but lacks guidance on local SIM/eSIM options, embassy contact, and hotel phone numbers/addresses as inputs to be collected per step (useful for acceptance testing and contingencies).
#
# 5. Minor clarity: Step names vs outputs labeling
#    - You swapped some labels (e.g., “Concrete outputs/artifacts” vs Planner’s “Outputs” and “Actionable tasks” vs “Activities”) which is fine but made Inputs omission less obvious. For strict matching against Planner criteria, add an explicit “Inputs” subsection under each step.
#
# Suggested concrete improvements (actionable)
# 1. Add an explicit "Inputs" subsection to Steps 1–5
#    - Example for Day 1 Inputs: hotel address & phone, check-in time, Viva Viagem card or cash, Castelo ticket (if purchased), phone with maps and charger, weather check.
#    - Make these short lists per day so acceptance testers can confirm pre-conditions.
#
# 2. Add per-day sample timeline with start/end times and time budgets
#    - For each day include a short sample schedule (e.g., 09:00 depart hotel → 10:00–12:00 Pena Palace → 12:30 lunch → 13:45 Moorish Castle → 16:00 Quinta da Regaleira → 17:30 train back) so reviewers can validate feasibility against real train schedules.
#
# 3. Provide alternative indoor/accessible options
#    - For rain: suggest alternatives (e.g., National Tile Museum or a tram museum in place of outdoor viewpoints).
#    - For limited mobility: indicate where taxis or shorter walking routes replace stairs/hills (e.g., skip Moorish Castle walk in favor of viewpoints reachable by taxi).
#
# 4. Per-day cost estimate and transport time table
#    - Add a small cost estimate per day (transport + entry fees + meals) and a short transport time table (typical transfer times between key nodes) to help acceptance testers evaluate budget/logistics.
#
# 5. Add recommended pre-travel communications
#    - Recommend saving hotel phone/address, embassy number, eSIM/SIM options, and restaurant contact in the travel folder for each day’s Inputs.
#
# 6. (Optional) Provide one sample date-specific mini-schedule
#    - Once a date or month is given, add one sample day with exact train times and a locked dinner reservation window to demonstrate end-to-end testability.
#
# Decision
# Not approved. The implementation is high quality and largely meets the Planner’s intent, but it does not fully satisfy the Planner’s explicit requirement to list "specific inputs/outputs" for each step (Inputs missing for Days 1–5) and would benefit from the contingency/mobility alternatives and per-day timelines/costs requested above.
#
# Next steps to reach approval
# - Add explicit Inputs subsections to Steps 1–5.
# - Add a concise per-day sample timeline (start/end times).
# - Add at least one indoor/rain or mobility-friendly alternative per affected day.
# - Add per-day cost estimates and short transport time table.
# - Optionally, include local sim/embassy/hotel phone as part of Inputs.
#
# Once those items are added, I will re-review and — if everything else remains as thorough and testable as it currently is — mark the implementation as APPROVED.
# TaskResult(messages=[TextMessage(id='772a2bd0-f524-4e97-b2da-1c6e6b34d280', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 23, 51, 349253, tzinfo=datetime.timezone.utc), content='\nCreate a 5 day travel itinerary to a random country of your choice. This itinerary should:\n- Include at least 2 activities per day\n- Be realistic in terms of travel time and logistics\n- Include a mix of cultural, historical, and leisure activities\n- The 4th night should include a special dining experience\n', type='TextMessage'), TextMessage(id='20460e9b-d513-49a2-967a-777408c6f7a4', source='Planner', models_usage=RequestUsage(prompt_tokens=157, completion_tokens=3146), metadata={}, created_at=datetime.datetime(2025, 10, 1, 4, 24, 18, 242532, tzinfo=datetime.timezone.utc), content='Random country chosen: Portugal — base: Lisbon with day trips to Sintra and Cascais. Below is a clear, actionable 5-day itinerary presented as numbered steps (Day 0 = pre-trip preparation + logistics), with specific inputs/outputs and testable acceptance criteria for each step.\n\nStep 0 — Pre-trip preparation (do this 2–14 days before travel)\n1) Activities\n   - Book round-trip flights to Lisbon (LIS).\n   - Reserve 4 nights accommodation in central Lisbon (Baixa/Chiado or Alfama recommended).\n   - Pre-book timed tickets for Pena Palace and Quinta da Regaleira (Sintra) and one museum in Lisbon if possible (MAAT or National Tile Museum).\n   - Make a dinner reservation for Day 4’s special dining experience (e.g., Belcanto — reserve at least 2–3 weeks ahead).\n   - Purchase or plan local transport: Viva Viagem card for tram/metro/bus and note train times for Sintra/Cascais day trips.\n2) Inputs\n   - Passport/ID, flight confirmation, hotel confirmation, restaurant confirmation, attraction reservations, estimated arrival/departure times.\n3) Outputs\n   - Confirmed flight + hotel + attraction and special-dinner reservations + local transport card plan.\n4) Acceptance criteria (testable)\n   - Flights and hotel are booked and confirmations saved (emails or screenshots).\n   - Pena Palace and Quinta da Regaleira timed tickets confirmed for Day 3.\n   - Special dining reservation confirmed for Day 4 evening (date/time, number of guests).\n   - Viva Viagem card or plan ready and train schedules checked for Sintra and Cascais.\n   - Travel insurance purchased (if desired).\n\nStep 1 — Day 1: Arrival + Alfama introduction (Arrival day; allow 3–6 hours depending on arrival)\n1) Activities (at least 2)\n   - Transfer from Lisbon Airport to hotel (taxi/ride-share ~20–35 min; metro ~35–45 min).\n   - Afternoon walking tour of Alfama: Castelo de São Jorge (historical) and viewpoints (Miradouro Santa Luzia).\n   - Optional evening: short tram ride (Tram 28) and casual dinner in Alfama.\n2) Travel/logistics notes\n   - Allow 30–60 min to get through airport and to hotel. Reserve 1.5–2.5 hours for Castelo and viewpoints. Tram 28 queues vary; plan 30–60 minutes if taking it.\n3) Inputs\n   - Hotel address + check-in time, castle tickets (on-site possible but allow queue time), local map or phone GPS, comfortable walking shoes.\n4) Outputs\n   - Checked in at hotel, explored Alfama and Castelo, evening meal near hotel.\n5) Acceptance criteria (testable)\n   - Hotel check-in completed by planned local time.\n   - Visited Castelo de São Jorge and taken photos from at least one Miradouro.\n   - Completed either a Tram 28 ride (boarded tram) or an Alfama evening stroll and had dinner in the neighborhood.\n\nStep 2 — Day 2: Belém district + LX Factory (Full day)\n1) Activities (at least 2)\n   - Morning: Belém — Jerónimos Monastery and Belém Tower (historical & cultural). Try Pastéis de Belém mid-morning.\n   - Afternoon: MAAT (Museum of Art, Architecture and Technology) or the National Coach Museum; riverside walk.\n   - Evening: LX Factory for shopping, galleries, and relaxed dinner (leisure/cultural).\n2) Travel/logistics notes\n   - From ce ...

# %% [markdown]
# NOTE: You'll notice that the output might contain duplicated text, that is because `Console` prints when a text message is sent and received.

# %% [markdown]
# ## Reflection & Analysis

# %% [markdown]
# ### What worked well?
# The agent system was quite good at providing detailed, coherent responses. The responses were generally in depth and thorough, covering required aspects and sometimes going above and beyond. The three pronged approach to answering a query/accomplishing a task worked well because it didn't overwhelm any singular agent, but instead allowed for each agent to execute its relative task to the fullest and produce a proper response.
#
# ### What struggled?
# The system struggled with following specific guidelines at times. For instance, it did not meet the 150 word requirement for the second task. Also, sometimes it did more than asked and went overboard with its responses, which could be both a good and bad thing.
#
# ### Potential improvements:
# One improvement could be providing some more distinction between the tasks/outcomes of the planning agent and the implementer agent. Sometimes the implementer agent would simply take the outputs of the planning agent and restructure the response, and would not add its own additions. Ensuring the planning agent only does planning might lead to a more efficient system.
#
# ### Tool integration:
# [Optional: Discuss how adding tools (like a calculator function) might improve the system]

# %% [markdown]
# # Optional Extensions

# %% [markdown]
# ## Adding Tools (Optional Challenge)
#
# Consider adding a simple tool function that agents can use, such as a calculator or text analyzer.

# %%
# Example tool function (uncomment and modify as needed)
# def calculator(expression: str) -> float:
#     """Simple calculator tool for basic mathematical operations"""
#     try:
#         # WARNING: eval() should not be used in production - use a proper math parser
#         result = eval(expression)
#         return result
#     except Exception as e:
#         return f"Error: {str(e)}"

# To integrate tools with AutoGen agents, you would typically:
# 1. Define tool schemas following MCP-like patterns
# 2. Register tools with specific agents  
# 3. Update system prompts to mention available tools
# 4. Handle tool calls in the conversation flow

# %% [markdown]
# # Summary and Next Steps

# %% [markdown]
# ## Key Takeaways
#
# - **Task Decomposition**: We learned that breaking down complex problems seems difficult at first, but when you clearly lay out the scope and take a look at the big picture, you are able to section out and identify independent tasks. You can then delegate these to, in our case, various agents that can come together to solve the problem.
# - **Agent Design**: We learned that when it comes to defining agent roles and responsibilities, it is important too never delegate too much or even too little to one agent. If you make an agent's task too complex, it may not be able to perform it effetively and that might indicate adding another agent. But if you provide the agent with a simple ask, it begs the question of whether an agent is needed in the first place. Ultimately, when building agents, the goal/output of the agent must be reasonable and clearly defined.
# - **Communication Protocols**: MCP is a standardized protocol used by agents to gain access to a series of tools, resources, and prompts. It facilitates agent->tool interactions. A2A on the other hand is a standardized agent->agent communication protocol. Agents built on different frameworks can communicate with easy. Our agent system in part 1 used various A2A interactions, as well having the user's codebase as a shared context / potential MCP tool.
#
# ## References
#
# - [AutoGen Documentation](https://microsoft.github.io/autogen/stable/index.html)
# - [Model Context Protocol](https://modelcontextprotocol.io/docs/getting-started/intro)
# - [Agent-to-Agent Protocol](https://a2a-protocol.org/latest/)
# - L2_overview.md (Lab requirements and detailed explanations)

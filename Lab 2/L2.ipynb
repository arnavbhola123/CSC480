# %% [markdown]
# # CSC 480-F25 Lab 2: Task Decomposition, Multi‑Agent Design Patterns, and Communication Protocols

# %% [markdown]
# # Authors:

# %% [markdown]
# ***Arnav Bhola, Pranav Krishna***
#
# California Polytechnic State University, San Luis Obispo;
#
# Computer Science & Software Engineering Department

# %% [markdown]
# # Overview
#
# This lab focuses on:
# - Breaking down complex problems into smaller tasks (task decomposition)
# - Defining specialized agents with clear roles and responsibilities
# - Choosing appropriate multi-agent design patterns
# - Specifying communication protocols between agents
# - Implementing a three-agent system using AutoGen
#
# NOTE: If you already know what you're going to do for your final project, you may use this lab to make progress on it. Otherwise, treat this lab as a distinct exercise.
#
# ## Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Decompose a complex problem into a comprehensive set of constituent tasks
# - Identify and define the roles, responsibilities, and abilities of individual agents
# - Select and justify an appropriate multi-agent design pattern (Manager‑Worker, Sequential Pipeline, Collaborative Team)
# - Explain and apply foundational agent communication protocols at a high level (MCP, A2A)
# - Start thinking about the architecture of your project (agents, tasks, design pattern, and interaction protocols)

# %% [markdown]
# # Part 1: Task Decomposition and Agent Design

# %% [markdown]
# ## 1. Problem Statement & Task Decomposition
#
# **Main Problem:** This agent will solve the issue of bug fixing in code files
#
# **Task Breakdown:** List the steps and sub-tasks needed to achieve the goal:
# 1. This agent will first find the code block(s) that are associated with the bug
# 2. This agent will patch/fix the bug and provide the new code
# 3. This agent will check the code to ensure the bug is fixed and no new errors are created by this fix. If a new error is created, it will repeat step 3.
#
# Agent Exits once code is working.

# %% [markdown]
# ## 2. Agent Definition
#
# Define your primary agents with clear roles and responsibilities:
#
# ### Agent 1: Bug Context Identifier Agent
# - **Role:** Worker Agent (Finds code chunks related to bug)
# - **Responsibilities:** Finds the code chunks related to the bug in context with the whole program
# - **Inputs:** Gets user input for the code as well as the description of the bug
# - **Outputs:** Returns the code chunks related to bug
# - **Success Criteria:** Successful if the agent returns a code chunk, if no code chunk returned, then bug doesn't exist
#
# ### Agent 2: Code Fixer Agent
# - **Role:** Worker Agent (Fixes the code chunk to patch the bug)
# - **Responsibilities:** Fixes the code chunk to patch the bug
# - **Inputs:** Recieves code chunks from Agent 1
# - **Outputs:** Outputs the updated/fixed code of the whole program
# - **Success Criteria:** Successful, if the agent returns the fixed code of the whole program, failed if it doesn't output any code or other unneeded content.
#
# ### Agent 3: QA Agent
# - **Role:** Manager Agent (Quality checks the code)
# - **Responsibilities:** Quality checks the code and if any errors are found, it will return a description of the bug and provide the code chunk back to agent 2.
# - **Inputs:** Recieves the full code of the "fixed" program
# - **Outputs:** Returns the code of the whole program
# - **Success Criteria:** Successful, if the agent returns the fixed code of the whole program, failed if it doesn't output any code or other unneeded content.

# %% [markdown]
# ## 3. Design Pattern Selection
#
# **Chosen Pattern:** Sequential Pipeline
#
# **Justification:** This pattern works since this follows a pipeline-like approach where it follows a series of steps to fix the code, and at the end there could be a cyclic step which repeats until errors are caught and fixed.

# %% [markdown]
# ## 4. Communication Design
#
# ### Model Context Protocol (MCP)
# **Shared Context & Tools:** [Describe the shared context and tools all agents need - schemas, access rules, etc.]
#
# ### Agent-to-Agent (A2A) Interactions
#
# #### Interaction 1: [User] → [Agent 1]
# - **Purpose:** This sends the full program code + bug description to Agent 1
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Message structure consists of the full program code and a description of the bug
#
# #### Interaction 2: [Agent 1] → [Agent 2]
# - **Purpose:** This sends the output of Agent 1 (the detected code blocks related to the bug) to Agent 2
# - **Key Fields:** Code field + bug description message
# - **Message Format:** Message structure consists of a code field and a description of the bug
#
# #### Interaction 3: [Agent 2] → [Agent 3]
# - **Purpose:** This sends the fixed code of the whole program to the QA agent
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Full program code and a description of the bug
#
# #### Interaction 4: [Agent 3] → [Agent 2]  (OPTIONAL)
# - **Purpose:** If issues are found by QA agent, this will send any new bugs/issues detected to Agent 2 to fix
# - **Key Fields:** Full code + description of bug
# - **Message Format:** Full program code and a description of the bug
#
# ### Exit

# %% [markdown]
# ## 5. Interaction Diagram
#
# [Create a flowchart or sequence diagram showing agents, your chosen pattern, and MCP/A2A interactions. You can use text-based diagrams, draw by hand and insert an image, or use diagramming tools.]
#
# #####
# Example text-based flow:
# User → Agent1 → Agent2 → Agent3 → User
#   ↓       ↓       ↓       ↓
#  MCP    A2A     A2A    Final
# Tool   Msg1    Msg2   Output
# ####
#
# ```
#                    ←    ←    ←
#                    ↓         ↑
# User → Agent 1 → Agent 2 → Agent 3 → Exit
#   ↓      ↓
#        A2A        A2A       A2A
# Msg1   Msg2       Msg3      Msg4
# ```

# %% [markdown]
# # Part 2: Three-Agent AutoGen Implementation

# %% [markdown]
# ## Environment Setup
#
# Install required packages and set up Azure OpenAI configuration.

# %%
# %pip install "autogen-core" "autogen-agentchat" "autogen-ext[openai,azure]"
# Out:
# Requirement already satisfied: autogen-core in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (0.7.5)
# Requirement already satisfied: autogen-agentchat in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (0.7.5)
# Requirement already satisfied: autogen-ext[azure,openai] in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (0.7.5)
# Requirement already satisfied: jsonref~=1.1.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (1.1.0)
# Requirement already satisfied: opentelemetry-api>=1.34.1 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (1.37.0)
# Requirement already satisfied: pillow>=11.0.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (11.3.0)
# Requirement already satisfied: protobuf~=5.29.3 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (5.29.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.10.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (2.11.9)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-core) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from pydantic<3.0.0,>=2.10.0->autogen-core) (0.4.1)
# Requirement already satisfied: azure-ai-inference>=1.0.0b9 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (1.0.0b9)
# Requirement already satisfied: azure-ai-projects>=1.0.0b11 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (1.1.0b4)
# Requirement already satisfied: azure-core in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (1.35.1)
# Requirement already satisfied: azure-identity in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (1.25.0)
# Requirement already satisfied: azure-search-documents>=11.4.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (11.5.3)
# Requirement already satisfied: aiofiles in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (24.1.0)
# Requirement already satisfied: openai>=1.93 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (2.0.0)
# Requirement already satisfied: tiktoken>=0.8.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from autogen-ext[azure,openai]) (0.11.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-ai-inference>=1.0.0b9->autogen-ext[azure,openai]) (0.7.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (12.26.0)
# Requirement already satisfied: azure-ai-agents>=1.2.0b3 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (1.2.0b5)
# Requirement already satisfied: requests>=2.21.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-core->autogen-ext[azure,openai]) (2.32.5)
# Requirement already satisfied: six>=1.11.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-core->autogen-ext[azure,openai]) (1.17.0)
# Requirement already satisfied: azure-common>=1.1 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-search-documents>=11.4.0->autogen-ext[azure,openai]) (1.1.28)
# Requirement already satisfied: cryptography>=2.1.4 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (46.0.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (2.0.0)
# Requirement already satisfied: pycparser in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=2.1.4->azure-storage-blob>=12.15.0->azure-ai-projects>=1.0.0b11->autogen-ext[azure,openai]) (2.23)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (0.11.0)
# Requirement already satisfied: sniffio in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from openai>=1.93->autogen-ext[azure,openai]) (4.67.1)
# Requirement already satisfied: idna>=2.8 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai>=1.93->autogen-ext[azure,openai]) (3.10)
# Requirement already satisfied: certifi in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.93->autogen-ext[azure,openai]) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from opentelemetry-api>=1.34.1->autogen-core) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.1->autogen-core) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from requests>=2.21.0->azure-core->autogen-ext[azure,openai]) (2.5.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from tiktoken>=0.8.0->autogen-ext[azure,openai]) (2025.9.18)
# Requirement already satisfied: colorama in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from tqdm>4->openai>=1.93->autogen-ext[azure,openai]) (0.4.6)
# Requirement already satisfied: msal>=1.30.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-identity->autogen-ext[azure,openai]) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from azure-identity->autogen-ext[azure,openai]) (1.3.1)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->autogen-ext[azure,openai]) (2.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_agentchat.conditions import TextMentionTermination
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\pranav files\college work\csc 480\lab2\.venv\lib\site-packages (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
from dotenv import load_dotenv

# %%
cwd = Path.cwd()
env_path = cwd.parent / ".env"
loaded = load_dotenv(env_path)

# %%
# This is the same as in L1
azure_deployment = os.getenv("AZURE_DEPLOYMENT_NAME")
api_version = "2024-12-01-preview"  # If you're using gpt-5-mini as demonstrated

# e.g. https://ccoha-mfoynknp-eastus2.cognitiveservices.azure.com/
azure_endpoint = os.getenv("AZURE_ENDPOINT")

# %% [markdown]
# ## An Example Three-Agent System Architecture
#
# Based on the suggested roles from the overview:
# - **Planner**: Decomposes the user goal into a concise, ordered plan
# - **Implementer**: Executes the steps from the plan
# - **Critic/Integrator**: Reviews output and suggests improvements or approves completion

# %%
async def setup_three_agent_system():
    """Set up the three-agent system with Planner, Implementer, and Critic roles"""
    
    # Create the Azure OpenAI client
    client = AzureOpenAIChatCompletionClient(
        azure_deployment=azure_deployment,
        model="gpt-5-mini",
        api_version=api_version,
        azure_endpoint=azure_endpoint,
        api_key=os.getenv("AZURE_SUBSCRIPTION_KEY"),
    )
    
    # Define the three agents with specific system prompts
    planner = AssistantAgent(
        name="Planner",
        model_client=client,
        system_message="""You are a task decomposition specialist. Your role is to:
        1. Break down complex user goals into clear, numbered steps
        2. Define specific inputs/outputs for each step  
        3. Provide testable acceptance criteria for each step
        4. Present plans in a structured, actionable format
        
        Always end your response with 'PLAN_COMPLETE' when finished."""
    )
    
    implementer = AssistantAgent(
        name="Implementer", 
        model_client=client,
        system_message="""You are an implementation specialist. Your role is to:
        1. Follow the Planner's steps methodically
        2. Address each step with concrete outputs/artifacts
        3. Provide detailed solutions that meet the specified criteria
        4. Ask for clarification if any step is unclear
        
        Always end your response with 'IMPLEMENTATION_COMPLETE' when finished."""
    )
    
    critic = AssistantAgent(
        name="Critic",
        model_client=client, 
        system_message="""You are a quality assurance specialist. Your role is to:
        1. Review the Implementer's work against the Planner's criteria
        2. Identify gaps, errors, or missing elements
        3. Suggest specific improvements if needed
        4. Only approve with 'APPROVED' if all criteria are fully met
        
        Be thorough but constructive in your feedback."""
    )
    
    return planner, implementer, critic

# %%
async def run_three_agent_workflow(task_description):
    """Run the three-agent workflow for a given task"""

    # Set up the agents
    planner, implementer, critic = await setup_three_agent_system()

    # Create termination condition - look for "APPROVED" in messages
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.base.html#autogen_agentchat.base.TerminationCondition
    termination = TextMentionTermination("APPROVED")

    # Create a group chat with the three agents
    # The RoundRobinGroupChat will manage turn-taking between agents
    # See https://microsoft.github.io/autogen/stable//reference/python/autogen_agentchat.teams.html#autogen_agentchat.teams.RoundRobinGroupChat
    team = RoundRobinGroupChat([planner, implementer, critic], termination_condition=termination)

    # Run the workflow
    print("Starting three-agent workflow...")
    print("=" * 60)

    # Start the conversation
    result = await Console(
        team.run_stream(task=task_description)
    )

    return result

# %% [markdown]
# ## Example Task 1: Analytical Task
#
# Test the three-agent system with a small example analytical task.

# %%
# Test Task 1: Compare sorting algorithms
analytical_task = """
Compare the pros and cons of Quick Sort vs Merge Sort algorithms. 
Provide a structured analysis that includes:
- Time and space complexity for both
- Best/worst case scenarios  
- Practical use cases for each
- A final recommendation with justification
"""

# Uncomment to run when ready:
# await run_three_agent_workflow(analytical_task)

# %% [markdown]
# ## Example Task 2: Creative Task
#
# Test the three-agent system with a creative writing task.

# %%
# Test Task 2: Creative writing with constraints  
creative_task = """
Write a 150-word summary of the benefits of renewable energy that:
- Uses exactly 3 specific statistics or data points
- Includes at least 2 types of renewable energy sources
- Has a compelling call-to-action in the final sentence
- Maintains an optimistic but factual tone throughout
"""

# Uncomment to run when ready:
# await run_three_agent_workflow(creative_task)

# %% [markdown]
# ## Your Task
#
# Write your own task for the planner-implementer-critic system

# %%
your_task = """
Create a 5 day travel itinerary to a random country of your choice. This itinerary should:
- Include at least 2 activities per day
- Be realistic in terms of travel time and logistics
- Include a mix of cultural, historical, and leisure activities
- The 4th night should include a special dining experience
"""

# Uncomment to run when ready:
await run_three_agent_workflow(your_task)
# Out:
# Starting three-agent workflow...
# ============================================================
# ---------- TextMessage (user) ----------
#
# Create a 5 day travel itinerary to a random country of your choice. This itinerary should:
# - Include at least 2 activities per day
# - Be realistic in terms of travel time and logistics
# - Include a mix of cultural, historical, and leisure activities
# - The 4th night should include a special dining experience
#
# ---------- TextMessage (Planner) ----------
# Step 1 — Choose a random country and base city
# - Action: Select a country at random and pick a practical base city that serves as a hub for day trips.
# - Inputs: none (random selection)
# - Outputs: Country = Portugal; Base city = Lisbon (LIS)
# - Acceptance criteria (testable):
#   1. A country is named (Portugal).
#   2. A base city is provided that has an international airport and regionally realistic day-trip connections (Lisbon, Humberto Delgado Airport - LIS).
#
# Step 2 — Confirm arrival/departure and local transport logistics
# - Action: Define realistic transfer times from airport to city, and typical transport modes for in-city and day-trip travel.
# - Inputs: Arrival airport code (LIS), base city (Lisbon)
# - Outputs: Recommended transfers and travel times:
#   - Airport → Lisbon city center by taxi: 20–30 min; by metro: 30–40 min.
#   - Lisbon local transit: metro/trams/buses/taxis/rideshare; typical intra-city travel 10–30 min between neighborhoods.
#   - Day trips: train Lisbon ↔ Sintra ~40 min; Lisbon ↔ Cascais (Cais do Sodré ↔ Cascais) ~40 min; Lisbon ↔ Évora bus/car ~1.5 hr.
# - Acceptance criteria:
#   1. Airport-to-city transfer times under 45 minutes are listed.
#   2. At least one realistic transit mode per route is included (taxi/metro/train/bus).
#   3. Day-trip travel times are within typical published ranges (Sintra ~40 min; Cascais ~40 min; Évora ~1.5 hr).
#
# Step 3 — Build the 5-day itinerary (day-by-day schedule with activities, timings, travel time, mix of cultural/historical/leisure). (This is the primary deliverable.)
# - Action: Produce a realistic 5-day itinerary based in Lisbon with day trips, at least 2 activities per day, and a special dining experience on night 4.
# - Inputs: Country & base city (Portugal, Lisbon), local travel times (Step 2)
# - Outputs: A detailed day-by-day itinerary (see below). Each day lists activity, suggested start time, estimated duration, transit time/mode, and notes (reservation suggestions where needed).
# - Acceptance criteria:
#   1. 5 calendar days provided.
#   2. Each day contains at least 2 distinct activities.
#   3. Activities are a mix of cultural, historical, and leisure across the trip.
#   4. Transit/travel time estimates are included and realistic.
#   5. Night 4 explicitly includes a special dining experience which is clearly described and time-specified.
#
# 5-Day Itinerary — Lisbon, Portugal (arrival/return at LIS)
# Day 1 — Arrival and Lisbon introduction
# - Morning / Arrival
#   - Activity: Arrive at Lisbon (LIS), transfer to hotel in Baixa/Chiado or Alfama.
#   - Start time: Varies by flight; plan 30–60 min for immigration + baggage, 20–30 min taxi to central hotel or 30–40 min metro.
#   - Duration: 1–1.5 hr (transfer + check-in)
#   - Notes: Choose central hotel to minimize intra-city travel.
# - Afternoon
#   - Activity 1: Walk Baixa and Chiado (Praça do Comércio, Rua Augusta, Santa Justa Elevator).
#   - Start time: ~14:00
#   - Duration: 1.5–2 hr
#   - Transit: short walks; elevator ride ~10–15 min.
#   - Activity type: Cultural + leisure
#   - Notes: Great orientation walk; many cafés.
# - Late afternoon / Evening
#   - Activity 2: Tram 28 ride through Alfama to São Jorge Castle (short scenic ride).
#   - Start time: ~16:30
#   - Duration: 1 hr (tram ride + short walks)
#   - Transit: Tram 28; expect queues—allow 15–30 min wait.
#   - Activity type: Cultural/historical
# - Evening
#   - Activity 3: Casual dinner in Chiado or Alfama.
#   - Start time: ~19:30
#   - Duration: 1.5–2 hr
#   - Notes: Light first-night meal; no heavy travel.
#
# Day 2 — Sintra day trip (palaces and historic town)
# - Morning
#   - Activity 1: Train to Sintra from Rossio station.
#   - Start time: 08:30
#   - Travel: ~40 min by suburban train
#   - Arrival in Sintra ~09:15
# - Mid-morning
#   - Activity 2: Visit Pena Palace and Park (buy timed ticket).
#   - Start time: ~10:00
#   - Duration: 2–2.5 hr (park is large; include photo stops + queue time)
#   - Transit: Short taxi or local bus from town center to Pena (~10–15 min).
#   - Activity type: Historical/cultural
# - Lunch
#   - Activity 3: Lunch in Sintra historic center (tasca or cafe).
#   - Start time: ~13:00
#   - Duration: 1 hr
# - Afternoon
#   - Activity 4: Moorish Castle (Castelo dos Mouros) or Quinta da Regaleira (choose one if short on time; both if time allows).
#   - Start time: ~14:30
#   - Duration: 1.5–2 hr
#   - Transit: 10–15 min between sites by foot/taxi
#   - Activity type: Historical/cultural/leisure (gardens, tunnels)
# - Early evening
#   - Activity 5: Return train to Lisbon
#   - Start time: Aim for train ~18:00
#   - Travel: ~40 min
#   - Evening dinner back in Lisbon ~19:30–20:00
# - Notes: Buy Pena Palace timed tickets in advance (high season). Wear comfortable shoes; hilly terrain.
#
# Day 3 — Belém, museums, and riverfront leisure
# - Morning
#   - Activity 1: Tram or taxi to Belém district (Jerónimos Monastery, Pastéis de Belém).
#   - Start time: ~09:00
#   - Duration: 2–3 hr (visit monastery, sample pastry)
#   - Transit: 15–25 min from central Lisbon
#   - Activity type: Historical/cultural
#   - Notes: Jerónimos Monastery has security lines—arrive early or book a time slot.
# - Midday
#   - Activity 2: Belém Tower and MAAT (Museum of Art, Architecture and Technology).
#   - Start time: ~11:30
#   - Duration: 1.5–2 hr
#   - Activity type: Historical + contemporary art/architecture
# - Afternoon
#   - Activity 3: Riverfront walk and LX Factory visit (creative district with shops, cafés).
#   - Start time: ~14:30
#   - Duration: 2–3 hr (coffee/lunch/shopping)
#   - Transit: 20–30 min by tram/taxi
#   - Activity type: Leisure + cultural
# - Evening
#   - Activity 4: Sunset at Miradouro de Santa Catarina or Portas do Sol, light dinner.
#   - Start time: ~18:30
#   - Duration: 1.5–2 hr
# - Notes: MAAT sometimes has late openings; check schedule.
#
# Day 4 — Coast day: Cascais & Guincho; special dining experience at night (Fado dinner)
# - Morning
#   - Activity 1: Train from Cais do Sodré to Cascais (coastal route).
#   - Start time: 09:00
#   - Travel time: ~40 min
#   - Activity type: Leisure (coastline scenic train)
# - Late morning
#   - Activity 2: Cascais historic center and marina; walk along waterfront.
#   - Start time: ~10:00
#   - Duration: 1.5–2 hr
# - Midday
#   - Activity 3: Short bus or taxi to Praia do Guincho (beach leisure, windsurfing views).
#   - Start time: ~12:30
#   - Travel: ~15–20 min
#   - Duration: 1.5–2 hr (relax, beach walk, seaside lunch or tapas)
#   - Activity type: Leisure / nature
# - Afternoon
#   - Activity 4: Return to Lisbon ~16:00 (train ~40 min), short rest at hotel.
#   - Arrival Lisbon ~17:00
# - Evening — Special dining experience (REQUIRED)
#   - Activity 5: Fado dinner in Alfama (reservable casa de fado with multi-course Portuguese tasting menu and live Fado performance). Example time: reservation for 20:00; doors ~19:45; performance ~20:30–22:30.
#   - Duration: 2–2.5 hr
#   - Activity type: Cultural + culinary (special dining)
#   - Notes: Book in advance (2–3 weeks recommended in high season); request a seat near the performers for best experience. Alternative: Michelin-starred seafood tasting menu in Belém or Chiado if user prefers haute cuisine.
# - Acceptance for Day 4 special dining:
#   1. Dinner is a clearly specified special experience (Fado dinner) with reservation advice and time.
#   2. Timing allows return from coastal trip and rest before dinner.
#
# Day 5 — Évora day trip or relaxed Lisbon morning + departure
# Option A — Full Évora day trip (recommended for history lovers)
# - Morning
#   - Activity 1: Bus or car to Évora (Rede Expressos bus or rented car).
#   - Start time: 08:00
#   - Travel: ~1.5 hr
# - Mid-morning
#   - Activity 2: Explore Évora UNESCO center (Roman Temple, Cathedral, Praça do Giraldo).
#   - Start time: ~10:00
#   - Duration: 2 hr
# - Lunch
#   - Activity 3: Local Alentejo lunch (try regional dishes: migas, açorda).
#   - Start time: ~12:30
#   - Duration: 1 hr
# - Afternoon
#   - Activity 4: Capela dos Ossos (Chapel of Bones) and leisurely walk back to station for return to Lisbon.
#   - Start time: ~14:00
#   - Return to Lisbon ~16:00–17:30 (depending on transport)
# - Evening
#   - Activity 5: Collect luggage and transfer to airport (timing dependent on flight).
# Option B — Short Lisbon morning + departure (if flight midday/early afternoon)
# - Morning
#   - Activity 1: Relaxed breakfast + quick visit to a nearby museum or viewpoint (National Tile Museum or Miradouro).
#   - Activity 2: Final shopping and transfer to airport per schedule.
# - Notes: Choose option based on departure time. For international late-evening flights, Évora day trip fits well.
#
# Step 4 — Reservation, timing, and booking checklist
# - Action: List what to reserve in advance and suggested timing.
# - Inputs: Itinerary (Step 3)
# - Outputs: Booking checklist:
#   1. Timed tickets: Pena Palace, Jerónimos Monastery (if visiting during high season) — reserve 2–4 weeks ahead.
#   2. Fado dinner reservation (night 4) — reserve 2–3 weeks ahead (or earlier for top casas).
#   3. Train tickets: For Sintra and Cascais you can buy on the spot; for intercity buses to Évora reserve 1–3 days ahead if traveling high season.
#   4. Airport transfer: book taxi/ride or schedule hotel shuttle same day or in advance for peace of mind.
#   5. Museum special exhibits: check openings and reserve where available.
# - Acceptance criteria:
#   1. All time-sensitive items (palace tickets, special dinner) are explicitly flagged to book in advance.
#   2. Transit items that can be booked on the spot are indicated as such.
#
# Step 5 — Practical tips, packing, and contingency
# - Action: Provide packing checklist, local tips, and contingency suggestions.
# - Inputs: Season assumed temperate (spring–fall); adjust if traveling in winter or summer heat.
# - Outputs:
#   - Packing essentials: comfortable walking shoes, light rain jacket, adapter (Type F/ C plug, 230V), sun hat/sunscreen, reusable water bottle.
#   - Documents: passport, travel insurance, printed/phone reservations.
#   - Money: euros; cards widely accepted; small cash for trams/tips.
#   - Language: Portuguese commonly used; basic English widely understood in Lisbon tourist areas.
#   - Tipping: modest — cafés rounding up, restaurants 5–10% if service not included.
#   - Contingency: If Pena Palace tickets unavailable, plan Quinta da Regaleira + Sintra historic center as backup; for bad weather on the coast, substitute Cascais indoor museums/LX Factory.
# - Acceptance criteria:
#   1. Practical items that affect daily execution (shoes, plug adapter, documents) are listed.
#   2. At least one contingency per major outdoor plan (Sintra/cape day & beach day) is suggested.
#
# Quick timeline summary for user copy-paste:
# - Day 1: Arrival → Baixa/Chiado walk → Tram 28 + São Jorge → Dinner
# - Day 2: Train to Sintra → Pena Palace → Moorish Castle/Quinta da Regaleira → Return
# - Day 3: Belém (Monastery, Pastéis, Tower) → MAAT → LX Factory → Sunset viewpoint
# - Day 4: Train to Cascais → Guincho beach → Return → Special Fado dinner (reserve)
# - Day 5: Évora day trip (or relaxed morning in Lisbon) → Departure
#
# Final acceptance checklist (for the entire plan):
# 1. Five days provided — yes.
# 2. At least two activities listed per day — yes (most days 3–5).
# 3. Mix of cultural, historical, and leisure activities — yes (palaces, monasteries, museums, beaches, Fado).
# 4. Travel time and logistics included and realistic — yes (airport transfers, train times, bus durations included).
# 5. Night 4 includes a special dining experience with reservation guidance — yes (Fado dinner in Alfama).
#
# If you’d like, I can:
# - Convert this into a printable day-by-day PDF-style itinerary with times tailored to your flight arrival/departure times.
# - Replace the Fado dinner with a Michelin-starred seafood tasting menu or a private chef experience if you prefer a different “special” dinner.
#
# PLAN_COMPLETE
# ---------- TextMessage (Implementer) ----------
# Step 1 — Random country and practical base city (artifact)
# - Country: Portugal
# - Base city (hub): Lisbon (Humberto Delgado Airport — LIS)
# - Why chosen: Lisbon is an international gateway with frequent regional rail/bus connections to Sintra, Cascais, and Évora; compact center (Baixa/Chiado/Alfama) minimizes transit time for sightseeing and evening dining.
#
# Step 2 — Arrival/departure and local transport logistics (artifact)
# - Airport → City center
#   - Taxi / ride-hail: 20–30 minutes (to Baixa/Chiado/Alfama), typical fare €10–€25 depending on time and luggage.
#   - Metro (red line + transfer): 30–40 minutes to central stations (Baixa-Chiado, Rossio) — one direct connection + walk or transfer.
#   - Prebooked private transfer: 25–35 minutes (useful for early/late flights or heavy luggage).
# - In-city transport
#   - Typical intra-neighborhood trips: 10–30 minutes by tram/taxi/metro/walk.
#   - Iconic tram routes: Tram 28 (touristy, slow scenic route through Alfama/Baixa), short hop tickets available. Expect queues during peak times.
#   - Ride-hail services: Bolt/Uber operate in Lisbon.
# - Day-trip travel times & modes (realistic)
#   - Lisbon (Rossio) ↔ Sintra: ~40 minutes by suburban train (CP Sintra line). Allow an extra 10–25 minutes to get from Sintra station up to Pena Palace by bus/taxi.
#   - Lisbon (Cais do Sodré) ↔ Cascais: ~35–45 minutes by coastal commuter train (scenic).
#   - Lisbon ↔ Évora: ~1.5 hours by Rede Expressos coach or ~1.25–1.5 hours by car (depending on traffic). Trains are longer/slower.
# - Acceptance checks met:
#   - Airport-city transfers under 45 minutes: yes.
#   - Realistic transit modes listed (taxi/metro/train/bus): yes.
#   - Day-trip travel times align with published ranges: yes.
#
# Step 3 — 5-day day-by-day itinerary (primary deliverable)
# Notes on assumptions: central Lisbon hotel in Baixa/Chiado or Alfama. Times are suggestions and realistic for moderate walking speed and short waits. Book time-sensitive visits in advance where noted.
#
# Day 1 — Arrival and Lisbon introduction
# - Morning / Arrival
#   - Activity: Arrive LIS → transfer to hotel in Baixa/Chiado or Alfama.
#   - Suggested start: at touchdown; allow 30–60 min for immigration+baggage, then 20–30 min taxi or 30–40 min metro to hotel.
#   - Duration: 1–1.5 hr (arrival → hotel check-in). If hotel check-in is later, leave luggage with reception.
#   - Notes: Choose centrally located hotel to reduce time between sights.
# - Afternoon
#   - Activity 1: Orientation walk — Praça do Comércio, Rua Augusta, Santa Justa Elevator, Rossio.
#   - Start: ~14:00
#   - Duration: 1.5–2 hr
#   - Transit: all walking; Santa Justa Elevator short queue (10–15 min).
#   - Type: Cultural + leisure
# - Late afternoon / Evening
#   - Activity 2: Tram 28 scenic ride through Alfama up to São Jorge Castle; short visit to the castle ramparts at sunset.
#   - Start: ~16:30
#   - Duration: 1–1.5 hr (allow 15–30 min tram wait; castle visit 30–45 min)
#   - Transit: Tram 28 + short uphill walk.
#   - Type: Cultural/historical
# - Night
#   - Activity 3: Casual dinner in Chiado or Alfama (try grilled fish or a small tasca — no rush).
#   - Start: ~19:30
#   - Duration: 1.5–2 hr
#   - Notes: Reserve if a popular restaurant; otherwise walk-ins fine in low season.
#
# Day 2 — Sintra day trip (palaces and historic town)
# - Morning
#   - Activity 1: Train Rossio → Sintra
#   - Start: 08:30
#   - Travel time: ~40 min train; arrive ~09:15
# - Mid-morning
#   - Activity 2: Pena Palace & Park (timed ticket strongly recommended)
#   - Start: ~10:00 (timed entry)
#   - Duration: 2–2.5 hr (explore palace interior + park viewpoints; allow photo stops and light queues)
#   - Transit: 10–15 min local bus or taxi up hill from Sintra station/town center.
#   - Type: Historical/cultural
# - Lunch
#   - Activity 3: Lunch in Sintra historic center (local tascas; quick pastelaria for queijadas if short on time)
#   - Start: ~13:00
#   - Duration: 1 hr
# - Afternoon
#   - Activity 4: Choose one or both depending on pace:
#     - Moorish Castle (Castelo dos Mouros): 1.5 hr, panoramic views; or
#     - Quinta da Regaleira: 1.5–2 hr, palace, initiatic wells, gardens.
#   - Start: ~14:30
#   - Transit: 10–20 min between sites on foot/taxi/local bus.
#   - Type: Historical/cultural/leisure
# - Early evening
#   - Activity 5: Return train to Lisbon; dinner back in Lisbon (~19:30)
#   - Start: Aim for train ~18:00
#   - Travel: ~40 min
# - Notes: If Pena timed entries sold out, switch to Quinta da Regaleira + Sintra town walk (excellent backup).
#
# Day 3 — Belém, museums, and riverfront leisure
# - Morning
#   - Activity 1: Travel to Belém (tram 15, bus, or taxi)
#   - Start: ~09:00
#   - Transit time: 15–25 min from central Lisbon
#   - Visit: Jerónimos Monastery (timed ticket advisable) + Pastéis de Belém (pastry)
#   - Duration: 2–3 hr (monastery 45–60 min; pastry + walk 30–45 min)
#   - Type: Historical/cultural
# - Midday
#   - Activity 2: Belém Tower + MAAT (Museum of Art, Architecture and Technology)
#   - Start: ~11:30
#   - Duration: 1.5–2 hr (tower exterior + MAAT exhibition)
#   - Type: Historical + contemporary art/architecture
# - Afternoon
#   - Activity 3: Return to central Lisbon → LX Factory (creative quarter) for lunch, shopping, galleries, and cafés
#   - Start: ~14:30
#   - Transit: ~20–30 min by tram/taxi
#   - Duration: 2–3 hr (browse shops, coffee, optional bookshop Ler Devagar)
#   - Type: Leisure + cultural
# - Evening
#   - Activity 4: Sunset viewpoint (Miradouro de Santa Catarina or Portas do Sol) then light dinner nearby
#   - Start: ~18:30
#   - Duration: 1.5–2 hr
# - Notes: Jerónimos and MAAT can have staggered opening hours — check ahead.
#
# Day 4 — Coast day: Cascais & Guincho; special dining experience at night (Fado dinner)
# - Morning
#   - Activity 1: Cais do Sodré → Cascais train (scenic coastal line)
#   - Start: 09:00
#   - Travel time: ~35–45 min
#   - Type: Leisure (coastal scenic)
# - Late morning
#   - Activity 2: Explore Cascais historic center, marina, and promenade
#   - Start: ~10:00
#   - Duration: 1.5–2 hr (light shopping/coffee)
# - Midday
#   - Activity 3: Bus or taxi to Praia do Guincho for beach stroll, windsurfer watching, and seaside lunch
#   - Start: ~12:30
#   - Travel: ~15–20 min
#   - Duration: 1.5–2 hr
#   - Type: Leisure/nature
# - Afternoon
#   - Activity 4: Return to Lisbon (train ~16:00), short rest at hotel
#   - Transit: ~40 min train
#   - Arrival: ~17:00–17:30
# - Evening — Special dining experience (required)
#   - Activity 5: Reserved Fado dinner in Alfama (casa de fado with multi-course Portuguese menu & live Fado)
#   - Reservation details:
#     - Reservation time: book a table for 20:00 (doors ~19:45); performance usually 20:30–22:30.
#     - Duration: 2–2.5 hr
#     - Transit: short taxi or walk from central hotel to Alfama (10–20 min depending on location)
#     - Example casas to consider (reserve early): Clube de Fado, Mesa de Frades, A Baiuca, Sr. Fado (local reputations vary).
#   - Type: Cultural + culinary (special, atmospheric)
#   - Notes: Book 2–3 weeks ahead in high season; request seat near performers. Alternative offered: Belcanto (Michelin) or Alma (Michelin-starred tasting) if user prefers haute cuisine — reserve earlier.
# - Acceptance check: Fado dinner is a clearly specified special experience with reservation guidance and timing allowing rest after coastal trip.
#
# Day 5 — Évora day trip OR relaxed Lisbon morning + departure (choose based on flight time)
# Option A — Évora day trip (recommended if you have a late afternoon/evening flight)
# - Morning
#   - Activity 1: Depart Lisbon (Rede Expressos bus from Sete Rios or car) to Évora
#   - Start: 08:00
#   - Travel: ~1.5 hr
# - Mid-morning
#   - Activity 2: Explore Évora UNESCO center (Roman Temple, Cathedral, Praça do Giraldo)
#   - Start: ~10:00
#   - Duration: 2 hr
# - Lunch
#   - Activity 3: Alentejo regional lunch (migas, açorda) in town
#   - Start: ~12:30
#   - Duration: 1 hr
# - Afternoon
#   - Activity 4: Visit Capela dos Ossos (Chapel of Bones), stroll back; depart for Lisbon ~15:30–16:00
#   - Return to Lisbon: ~16:30–17:30 (depends on transport)
# - Evening
#   - Activity 5: Collect luggage / transfer to LIS per flight schedule
# Option B — Relaxed Lisbon morning + departure (recommended if you have an early/ midday flight)
# - Morning
#   - Activity 1: Leisure breakfast + quick viewpoint (National Tile Museum if nearby)
#   - Activity 2: Final shopping in Baixa/Chiado; check out and transfer to airport allowing recommended arrival time (2–3 hours before international flight).
# - Notes: Choose option based on your outbound flight time.
#
# Step 4 — Reservation, timing, and booking checklist (artifact)
# - High-priority advance reservations (book early)
#   1. Pena Palace timed tickets — reserve 2–4 weeks in high season.
#   2. Jerónimos Monastery and/or Belém Tower (timed entry, if showing available) — reserve 1–3 weeks ahead for summer.
#   3. Fado dinner (night 4) — reserve 2–3 weeks ahead (or earlier for top casas). Specify seating preference (near performers) if possible.
#   4. Évora bus/train (Rede Expressos): book 1–3 days ahead for busy travel days; earlier for holiday weekends.
#   5. Michelin or specialty restaurants (Belcanto, Alma) — reserve 3–6 weeks ahead if choosing alternative special dinner.
# - Lower-priority / on-the-day purchases
#   - Sintra & Cascais commuter train tickets: can be bought at stations on the day (but allow time for queue at Rossio for Sintra in morning peak).
#   - Tram 28 tickets: buy single ticket onboard or use Viva Viagem card; expect lines in peak season.
#   - Local taxis/ride-hails: book on the spot or via app.
# - Airport transfer
#   - Book private transfer in advance if arriving late at night / with lots of luggage; otherwise taxis and metro are reliable.
# - Museum special exhibitions
#   - Check MAAT exhibit schedules and book if a specific temporary exhibition is targeted.
#
# Step 5 — Practical tips, packing, and contingency (artifact)
# - Packing essentials
#   - Comfortable walking shoes (cobblestones and hills).
#   - Light layers and a windproof jacket (coastal breeze and variable evenings).
#   - Plug adapter: Type C / Type F compatible plugs; voltage 230 V.
#   - Sunscreen, sunglasses, sun hat (especially for coastal days).
#   - Reusable water bottle (tap water in Lisbon is safe).
#   - Copies of passport, reservations (PDFs on phone & one paper copy).
# - Money & cards
#   - Currency: euro (EUR). Cards widely accepted; keep small cash for trams, small cafés and tips.
# - Language & etiquette
#   - Portuguese is official; English widely spoken in tourist areas. Simple Portuguese greetings are appreciated (Olá, Bom dia, Obrigado/a).
#   - Tipping: modest, usually rounding up or 5–10% in restaurants if service is good.
# - Health & safety
#   - Watch for pickpockets in crowded tram 28 and train stations — keep valuables secure.
# - Contingencies (at least one per major outdoor plan)
#   - Sintra (Pena): If timed tickets sold out or poor weather, prioritize Quinta da Regaleira and the historic town center; both are largely enjoyable in light rain with covered spots.
#   - Cascais / Guincho beach: If weather or rough seas make beach time unpleasant, spend extra time in Cascais museums (Casa das Histórias Paula Rego), or return early and visit LX Factory / MAAT exhibitions.
#   - Fado dinner unavailable: Reserve a Michelin tasting menu (Belcanto in Chiado or Alma) or a private chef table experience; both require earlier booking but are excellent special-dinner alternatives.
#   - Évora trip: If buses are full, consider a half-day trip to Óbidos or take a relaxed morning in Lisbon with the tile museum and markets.
# - Connectivity
#   - Consider a portable battery pack for full day outings; free Wi-Fi is common in cafés but not everywhere.
# - Weather notes by season
#   - Spring/Autumn: cool mornings/evenings; layers advised.
#   - Summer: sun and heat in the afternoon; coastal breeze mitigates heat but inland (Évora) can be hot.
#   - Winter: milder but rainy — check forecasts and bring waterproof layers.
#
# Quick copy-paste timeline summary
# - Day 1: Arrival → Baixa/Chiado walk → Tram 28 + São Jorge → Dinner
# - Day 2: Train to Sintra → Pena Palace → Moorish Castle/Quinta da Regaleira → Return
# - Day 3: Belém (Jerónimos Monastery, Pastéis) → Belém Tower + MAAT → LX Factory → Sunset viewpoint
# - Day 4: Train to Cascais → Guincho beach → Return to Lisbon → Special Fado dinner (reserve)
# - Day 5: Évora day trip (or relaxed Lisbon morning) → Departure
#
# Final practical checklist before travel (artifact)
# - Booked/To book:
#   - Pena Palace timed ticket: [ ] Reserved
#   - Jerónimos Monastery / MAAT: [ ] Reserved if required
#   - Fado dinner (Night 4): [ ] Reserved
#   - Évora bus (if taking day trip): [ ] Reserved
#   - Airport transfer: [ ] Booked or note taxi/metro plan
# - Daypack items: shoes, layer, hat, adapter, phone charger, printed reservations.
# - Documents: passport, travel insurance, payment cards, train/bus tickets (PDFs/printouts).
#
# Questions for you / customization options (please confirm)
# - Do you want the special dinner to be Fado in a traditional casa (as above) or would you prefer a Michelin-starred tasting menu instead? I can swap and supply specific restaurant names and booking links.
# - What are your flight arrival and departure times? I can then tailor start times and the Day 5 option precisely and generate an hourly printable itinerary.
#
# If you’d like, I can convert this into a printable PDF-style itinerary or produce a version with estimated costs and reservation links. Please tell me which option you prefer.
#
# IMPLEMENTATION_COMPLETE
# ---------- TextMessage (Critic) ----------
# Review summary against Planner criteria
#
# All required elements are present and realistic:
# - Step 1: Country (Portugal) and base city (Lisbon — Humberto Delgado Airport, LIS) named. Acceptance criteria met.
# - Step 2: Airport → city transfer times and in-city/day-trip transit modes and durations are realistic and within the ranges specified (taxi/metro/train/bus included). Acceptance criteria met.
# - Step 3: A 5-day itinerary is provided. Each day includes at least two activities, suggested start times, durations, transit modes/time estimates, and reservation notes where appropriate. Cultural, historical, and leisure activities are well balanced. Night 4 explicitly includes a special dining experience (Fado dinner) with reservation guidance and timing. Acceptance criteria met.
# - Step 4: Reservation checklist flags time-sensitive items (Pena Palace, Fado dinner, etc.) and distinguishes items that can be bought same-day. Acceptance criteria met.
# - Step 5: Packing, local tips, and contingencies are present (including at least one contingency per major outdoor plan). Acceptance criteria met.
#
# Gaps, minor errors, or places to improve (specific, actionable)
#
# 1. Day 5 Option B (relaxed Lisbon morning) — timing specifics
#    - Issue: Option B omits suggested start times/durations for the morning activities (breakfast, viewpoint, shopping) and the recommended time to leave for the airport relative to flight time.
#    - Suggestion: Add example timings (e.g., breakfast 08:00–09:00, quick viewpoint 09:15–09:45, shop 10:00–11:00, depart hotel by 11:00 for a 14:00 international flight allowing 3 hours at LIS).
#
# 2. Transit-card recommendation (practical convenience)
#    - Issue: The itinerary references single onboard tickets and Viva Viagem in one place, but doesn't explicitly recommend getting a Viva Viagem/contactless card for multiple days.
#    - Suggestion: Recommend buying/loading a Viva Viagem or rechargeable public-transport card on arrival for easier tram/metro/bus use and to speed transfers (especially useful for Tram 28, tram 15 to Belém, and trains).
#
# 3. Local cost/price context
#    - Issue: Few price estimates (only a taxi fare range was included). Users often appreciate rough cost ranges for major items (palace tickets, typical Fado dinner price per person, train/bus fares).
#    - Suggestion: Add approximate costs (example: Pena Palace €14–€20, Belém Tower/Monastery €6–€10, commuter train Lisbon→Sintra €2.25 one-way, Cascais train €2–€3, Fado dinner €35–€70+ depending on place).
#
# 4. Accessibility and mobility notes
#    - Issue: Several sites (Pena Palace grounds, São Jorge Castle, Alfama streets) involve hills and many cobblestones; the plan mentions comfortable shoes but could be clearer for travelers with limited mobility.
#    - Suggestion: Call out which activities are steep/hilly and recommend alternatives or transport options (taxis/local tourist buses) for visitors who need to avoid stairs/steep walks.
#
# 5. Confirmation of opening hours / seasonal caveats
#    - Issue: The plan advises to check MAAT and museum hours, but could remind the user that some casas de fado have fixed-performance schedules or cover charges separate from meal price.
#    - Suggestion: Add a note to confirm house rules/cover charges for casas de fado and verify museum/monument seasonal opening hours before booking.
#
# 6. Minor clarity edits
#    - Example: For Day 1 Tram 28 — emphasize long queues and high pickpocket risk more prominently (you note both elsewhere, but it helps to add next to the Tram 28 item itself).
#    - Example: For airport metro route, specify if luggage requires transfers (red line to Alameda + green to Baixa-Chiado etc.) or a simple transfer pattern so users can plan easier.
#
# Decision
#
# All primary and acceptance criteria from the Planner are fully met. The items above are enhancements rather than required corrections.
#
# APPROVED
#
# If you want, I can produce a tightened version incorporating the improvements above (Viva Viagem recommendation, sample costs, mobility notes, and explicit Day 5 Option B timings) and output it as a one-page printable timeline.
# TaskResult(messages=[TextMessage(id='39804a89-8831-4f0c-a4b1-4f313676f507', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 9, 30, 23, 51, 15, 513695, tzinfo=datetime.timezone.utc), content='\nCreate a 5 day travel itinerary to a random country of your choice. This itinerary should:\n- Include at least 2 activities per day\n- Be realistic in terms of travel time and logistics\n- Include a mix of cultural, historical, and leisure activities\n- The 4th night should include a special dining experience\n', type='TextMessage'), TextMessage(id='8d8e9a48-75dc-4da2-8a46-29dbbbd143a9', source='Planner', models_usage=RequestUsage(prompt_tokens=157, completion_tokens=4761), metadata={}, created_at=datetime.datetime(2025, 9, 30, 23, 52, 9, 531110, tzinfo=datetime.timezone.utc), content='Step 1 — Choose a random country and base city\n- Action: Select a country at random and pick a practical base city that serves as a hub for day trips.\n- Inputs: none (random selection)\n- Outputs: Country = Portugal; Base city = Lisbon (LIS)\n- Acceptance criteria (testable):\n  1. A country is named (Portugal).\n  2. A base city is provided that has an international airport and regionally realistic day-trip connections (Lisbon, Humberto Delgado Airport - LIS).\n\nStep 2 — Confirm arrival/departure and local transport logistics\n- Action: Define realistic transfer times from airport to city, and typical transport modes for in-city and day-trip travel.\n- Inputs: Arrival airport code (LIS), base city (Lisbon)\n- Outputs: Recommended transfers and travel times:\n  - Airport → Lisbon city center by taxi: 20–30 min; by metro: 30–40 min.\n  - Lisbon local transit: metro/trams/buses/taxis/rideshare; typical intra-city travel 10–30 min between neighborhoods.\n  - Day trips: train Lisbon ↔ Sintra ~40 min; Lisbon ↔ Cascais (Cais do Sodré ↔ Cascais) ~40 min; Lisbon ↔ Évora bus/car ~1.5 hr.\n- Acceptance criteria:\n  1. Airport-to-city transfer times under 45 minutes are listed.\n  2. At least one realistic transit mode per route is included (taxi/metro/train/bus).\n  3. Day-trip travel times are within typical published ranges (Sintra ~40 min; Cascais ~40 min; Évora ~1.5 hr).\n\nStep 3 — Build the 5-day itinerary (day-by-day schedule with activities, timings, travel time, mix of cultural/historical/leisure). (This is the primary deliverable.)\n- Action: Produce a realistic 5-day itinerary based in Lisbon with day trips, at least 2 activities per day, and a special dining experience on night 4.\n- Inputs: Country & base city (Portugal, Lisbon), local travel times (Step 2)\n- Outputs: A detailed day-by-day itinerary (see below). Each day lists activity, suggested start time, estimated duration, transit time/mode, and notes (reservation suggestions where needed).\n- Acceptance criteria:\n  1. 5 calendar days provided.\n  2. Each day contains at least 2 distinct activities.\n  3. Activities are a mix of cultural, historical, and leisure across the trip.\n  4. Transit/travel time estimates are included and realistic.\n  5. Night 4 explicitly includes a special dining experience which is clearly described and time-specified.\n\n5-Day Itinerary — Lisbon, Portugal (arrival/return at LIS)\nDay 1 — Arrival and Lisbon introduction\n- Morning / Arrival\n  - Activity: Arrive at Lisbon (LIS), transfer to hotel in Baixa/Chiado or Alfama.\n  - Start time: Varies by flight; plan 30–60 min for immigration + baggage, 20–30 min taxi to central hotel or 30–40 min metro.\n  - Duration: 1–1.5 hr (transfer + check-in)\n  - Notes: Choose central hotel to minimize intra-city travel.\n- Afternoon\n  - Activity 1: Walk Baixa and Chiado (Praça do Comércio, Rua Augusta, Santa Justa Elevator).\n  - Start time: ~14:00\n  - Duration: 1.5–2 hr\n  - Transit: short walks; elevator ride ~10–15 min.\n  - Activity type: Cultural + leisure\n  - Notes: Great orientation walk; many cafés.\n- Late afternoon / Evening\n  - Activity 2: Tram 28 ride through Alfama to São Jorg ...

# %% [markdown]
# NOTE: You'll notice that the output might contain duplicated text, that is because `Console` prints when a text message is sent and received.

# %% [markdown]
# ## Reflection & Analysis

# %% [markdown]
# ### What worked well?
# The agent system was quite good at providing detailed, coherent responses. The responses were generally in depth and thorough, covering required aspects and sometimes going above and beyond. The three pronged approach to answering a query/accomplishing a task worked well because it didn't overwhelm any singular agent, but instead allowed for each agent to execute its relative task to the fullest and produce a proper response.
#
# ### What struggled?
# The system struggled with following specific guidelines at times. For instance, it did not meet the 150 word requirement for the second task. Also, sometimes it did more than asked and went overboard with its responses, which could be both a good and bad thing.
#
# ### Potential improvements:
# One improvement could be providing some more distinction between the tasks/outcomes of the planning agent and the implementer agent. Sometimes the implementer agent would simply take the outputs of the planning agent and restructure the response, and would not add its own additions. Ensuring the planning agent only does planning might lead to a more efficient system.
#
# ### Tool integration:
# [Optional: Discuss how adding tools (like a calculator function) might improve the system]

# %% [markdown]
# # Optional Extensions

# %% [markdown]
# ## Adding Tools (Optional Challenge)
#
# Consider adding a simple tool function that agents can use, such as a calculator or text analyzer.

# %%
# Example tool function (uncomment and modify as needed)
# def calculator(expression: str) -> float:
#     """Simple calculator tool for basic mathematical operations"""
#     try:
#         # WARNING: eval() should not be used in production - use a proper math parser
#         result = eval(expression)
#         return result
#     except Exception as e:
#         return f"Error: {str(e)}"

# To integrate tools with AutoGen agents, you would typically:
# 1. Define tool schemas following MCP-like patterns
# 2. Register tools with specific agents  
# 3. Update system prompts to mention available tools
# 4. Handle tool calls in the conversation flow

# %% [markdown]
# # Summary and Next Steps

# %% [markdown]
# ## Key Takeaways
#
# - **Task Decomposition**: [Your insights about breaking down complex problems]
# - **Agent Design**: [What you learned about defining agent roles and responsibilities]
# - **Communication Protocols**: [Understanding of MCP and A2A interactions]
#
# ## References
#
# - [AutoGen Documentation](https://microsoft.github.io/autogen/stable/index.html)
# - [Model Context Protocol](https://modelcontextprotocol.io/docs/getting-started/intro)
# - [Agent-to-Agent Protocol](https://a2a-protocol.org/latest/)
# - L2_overview.md (Lab requirements and detailed explanations)
